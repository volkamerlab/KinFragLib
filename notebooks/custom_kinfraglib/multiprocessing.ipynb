# %%
import multiprocessing as mp

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import math
from pathlib import Path

import pandas as pd
#import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem, Draw, Lipinski, PandasTools

from kinfraglib import utils
from kinfraglib import filters
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: to-Python converter for boost::shared_ptr<RDKit::FilterCatalogEntry const> already registered; second conversion method ignored.

# %%
# Needed to display ROMol images in DataFrames
PandasTools.RenderImagesInAllDataFrames(images=True)

# %%
# Path to data
HERE = Path(_dh[-1])
PATH_DATA = HERE / '../../data'

# %%
fragment_library = utils.read_fragment_library(PATH_DATA / 'fragment_library')

# %%
fragment_library = filters.prefilters.pre_filters(
    fragment_library)

# %%
pains_dict = filters.pains.get_pains(fragment_library)

# %%
fragment_library = pains_dict["fragment_library"]

# %%
HERE = Path(_dh[-1])
DATA =  HERE / '../../../Brenk'

# %%
brenk_dict = filters.unwanted_substructures.get_brenk(fragment_library, DATA)
# Out:
# Number of unwanted substructures in Brenk et al. collection: 104

# %%
fragment_library =  brenk_dict['fragment_library']

# %%
druglikeness_dict = filters.ruleofthree.get_ro3_frags(fragment_library)
fragment_library = druglikeness_dict["fragment_library"]

# %%
res_qed = filters.qed.get_qed(fragment_library)
fragment_library = res_qed["fragment_library"]

# %%
synthesizability_dict = filters.building_blocks.check_building_blocks(
    fragment_library,
    str(str(PATH_DATA)+'/filters/DataWarrior/Enamine_Building_Blocks.sdf'))

# %%
fragment_library = synthesizability_dict['fragment_library']

# %%
d_sybas = filters.syba.calc_syba(
    fragment_library,
    cutoff=0)

# %%
fragment_library = d_sybas['fragment_library']

# %%
fragment_library = filters.analysis.number_of_accepted(
    fragment_library, columns=['bool_pains', 'bool_brenk', 'ro3', 'qed', 'bool_bb', 'bool_syba'],
    min_accepted=6)

# %%
for subpocket in fragment_library.keys():
    fragment_library[subpocket].drop(fragment_library[subpocket].loc[fragment_library[subpocket]['bool']==0].index, inplace=True)
    fragment_library[subpocket] = fragment_library[subpocket].reset_index(drop=True)

# %%
def get_tuple(fragment, dummy_atoms):

    """
    **copied from https://github.com/volkamerlab/KinaseFocusedFragmentLibrary/blob/b7e684c26f75efffc2a9ba2383c9027cdd4c29a3/kinase_focused_fragment_library/recombination/classes_meta.py**  # noqa: E501
    For a given fragment, returns:
    - smiles string with generic dummy atoms (dummy labels removed)
    - dummy atoms as tuples of frag_atom_id and subpocket (of the dummy = neighboring subpocket of
    the fragment)
    Parameters
    ----------
    fragment: RDKit Mol object
    dummy_atoms: list(RDKit Atom objects)
        list of all dummy atoms of the fragment
    Returns
    -------
    String
        SMILES string of the fragment
    frozenset(tuple)
        frozenset of tuples for each dummy atom containing the frag_atom_id and the subpocket of
        the dummy
    """

    frag_smiles = fragment
    # replace dummys with generic dummys (without atom number)
    # dummy tuple: (frag_atom_id, neighboring_subpocket), e.g. (AP_4, FP)
    dummy_set = []
    for dummy in dummy_atoms:
        frag_smiles = Chem.ReplaceSubstructs(
            frag_smiles, Chem.MolFromSmiles(dummy.GetSmarts()), Chem.MolFromSmiles("*")
        )[0]
        dummy_tuple = dummy.GetProp("frag_atom_id"), dummy.GetProp("subpocket")
        dummy_set.append(dummy_tuple)
    frag_smiles = Chem.MolToSmiles(frag_smiles)

    dummy_set = frozenset(dummy_set)

    return frag_smiles, dummy_set


class Compound:

    """
    **copied from https://github.com/volkamerlab/KinaseFocusedFragmentLibrary/blob/b7e684c26f75efffc2a9ba2383c9027cdd4c29a3/kinase_focused_fragment_library/recombination/classes_meta.py**  # noqa: E501
    Represents a combination of fragments including its dummy atoms
    Attributes
    ----------
    frag_ids: list(str)
        Strings representing the fragments that the molecule consists of
    subpockets: list(str)
        Subpockets that the molecule is targeting
    ports: list(Port)
        Port objects representing the dummy atoms of the molecule
    bonds: list(tuple(str))
        Bonds through which the fragments are connected.
        The bonds are stored as tuples of atom IDs.
    """

    def __init__(self, frag_ids, subpockets, ports, bonds):

        self.frag_ids = frag_ids
        self.subpockets = subpockets
        self.ports = ports
        self.bonds = bonds


class Fragment:

    """
    **copied from https://github.com/volkamerlab/KinaseFocusedFragmentLibrary/blob/b7e684c26f75efffc2a9ba2383c9027cdd4c29a3/kinase_focused_fragment_library/recombination/classes_meta.py**  # noqa: E501
    Represents a single fragment from the fragment library
    Attributes
    ----------
    frag_id: str
        ID of the fragment: subpocket_ID, e.g. AP_5
    subpocket: str
        Subpocket that the fragment is targeting
    ports: list(Port)
        Port objects representing the dummy atoms of the fragment
    """

    def __init__(self, frag_id, subpocket, ports):

        self.frag_id = frag_id
        self.subpocket = subpocket  # list of targeted subpockets
        self.ports = ports  # list of Port objects


class Port:

    """
    **copied from https://github.com/volkamerlab/KinaseFocusedFragmentLibrary/blob/b7e684c26f75efffc2a9ba2383c9027cdd4c29a3/kinase_focused_fragment_library/recombination/classes_meta.py**  # noqa: E501
    Represents a single dummy atom
    Attributes
    ----------
    atom_id: str
        frag_atom_id of the dummy atom
    subpocket: str
        Subpocket of the atom adjacent to the dummy atom (subpocket of the fragment containing
        the dummy)
    neighboring_subpocket: str
        Subpocket of the dummy atom
    bond_type: str
        Type of the bond connecting the dummy to its adjacent atom
    environment: str
        Type of the environment of the current fragment (of the adjacent atom)
    """

    def __init__(
        self, atom_id, subpocket, neighboring_subpocket, bond_type, environment
    ):

        self.atom_id = atom_id
        self.subpocket = subpocket
        self.neighboring_subpocket = neighboring_subpocket
        self.bond_type = bond_type
        self.environment = environment


class Combination:

    """
    **copied from https://github.com/volkamerlab/KinaseFocusedFragmentLibrary/blob/b7e684c26f75efffc2a9ba2383c9027cdd4c29a3/kinase_focused_fragment_library/recombination/classes_meta.py**  # noqa: E501
    Comparable representation of a combination of fragments
    Attributes
    ----------
    frag_ids: frozenset(str)
        Strings representing the fragments that the molecule consists of
    bonds: frozenset(tuple(str))
        Bonds through which the fragments are connected.
        The bonds are stored as tuples of atom IDs.
    Methods
    ----------
    __eq__()
        Two Combination objects are equal if they consist of the same fragments which are
        connected through the same bonds.
    """

    def __init__(self, frag_ids, bonds=None):
        self.frag_ids = frag_ids
        self.bonds = bonds

    def __eq__(self, other):
        return self.frag_ids == other.frag_ids and self.bonds == other.bonds

    def __ne__(self, other):
        return not self.__eq__(other)

    def __hash__(self):
        return hash((self.frag_ids, self.bonds))

# %%
def get_valid_pairs(fragment_library):
    """
        *copied and adapted from kinase_focused_fragment_library*
    """
    data = {}  # (Fragments)
    frag_set = set()  # only used in initialization for avoiding duplicates in fragment data set (smiles & dummy atoms)

    #iterate through subpockets and fragments in subpockets
    #save subpocket_fragmentindex and dummy atoms, bonds etc
    for subpocket in fragment_library.keys():
        fragments = []
        for i, row in fragment_library[subpocket].iterrows():
            #get fragment and connecting subpockets
            fragment = row['ROMol_original']
            fragment = Chem.RemoveHs(fragment)
            frag_id = f'{subpocket}_{i}'
            
            # store unique atom identifiers
            for a, atom in enumerate(fragment.GetAtoms()):
                frag_atom_id = f'{subpocket}_{a}'
                atom.SetProp('frag_atom_id', frag_atom_id)
                
            # get all dummy atoms of this fragment except the ones corresponding to the X pool
            dummy_atoms = [a for a in fragment.GetAtoms() if a.GetSymbol() == '*' and not a.GetProp('subpocket').startswith('X')]
            if not dummy_atoms:
                continue
            
            frag_smiles, dummy_set = get_tuple(fragment, dummy_atoms)
            # check if this exact fragment has already been found
            if (frag_smiles, dummy_set) in frag_set:
                continue
            # if not, add this fragment to set of fragments
            frag_set.add((frag_smiles, dummy_set))

            # create dummy atom objects
            ports = [Port(atom_id=dummy.GetProp('frag_atom_id'), subpocket=subpocket, neighboring_subpocket=dummy.GetProp('subpocket'),
                          bond_type=fragment.GetBondBetweenAtoms(dummy.GetIdx(), dummy.GetNeighbors()[0].GetIdx()).GetBondType(),
                          environment=dummy.GetNeighbors()[0].GetProp('environment'))
                     for dummy in dummy_atoms]   
            # add all dummy atoms of this fragment to the queue
            #compound = Compound(frag_ids=[frag_id], subpockets=[subpocket], ports=ports, bonds=[])
            #combo = Combination(frag_ids=frozenset([frag_id]))
            
            # store fragment in constant data set
            fragment = Fragment(frag_id=frag_id, subpocket=subpocket, ports=ports)
            fragments.append(fragment)
        data[subpocket] = fragments
        
    n_frags = len(frag_set)

    print('Number of fragments: ', n_frags)
    
    return data

# %%
def checkvalid(data, fragment_library):
    matches = [] #save matching fragment pairs
    #iterate through subpockets
    for subpocket in fragment_library.keys():
        #iterate through fragments in subpockets
        for fragment in data[subpocket]:
            fragment_id1 = fragment.frag_id #store fragment ID of first fragment in pair
            #go through atom connnections and check neighbors, bond type and environment
            for i in range(0,len(fragment.ports)):
                neighbor = fragment.ports[i].neighboring_subpocket
                bond_type = fragment.ports[i].bond_type
                environment = fragment.ports[i].environment
                match = [] #store current matching fragment pair
                for frag2 in data[neighbor]:
                    fragment_id2 = frag2.frag_id  #store fragment ID of second fragment            
                    for i in range(0,len(frag2.ports)): 
                        #check environment type, subpocket, bond type
                        environment_match = filters.brics_rules.is_brics_bond(environment, frag2.ports[i].environment) #check if BRICS environments are able to form connection
                        #if subpocket is adjacent, bond type is eqal and environments are matching, add as valid matching pair
                        if frag2.ports[i].neighboring_subpocket == subpocket and neighbor ==  frag2.ports[i].subpocket and frag2.ports[i].bond_type == bond_type and environment_match:
                            match.append([fragment_id1, fragment_id2])        
                matches.append(match) #add valid matching pair to list of matching pairs
    return matches

# %%
res = get_valid_pairs(fragment_library)
# Out:
# Number of fragments:  487

# %%
valids = checkvalid(res, fragment_library)

# %%
def get_bonds(valids, data, fragment_library):
    bonds = [] #store bonds of valid matching pairs as atom IDs where connection is formed
    #go through all valid pairs
    for valid in valids:
        bond = []
        for val in valid:
            #load fragments that should get connected
            subpocket1 = val[0].split("_")[0]
            fragment1_index = int(val[0].split("_")[1])
            fragment1 = fragment_library[subpocket1]["ROMol_original"][fragment1_index] 
            #remove Hs before finding bonds otherwise bond ids not correct because for combining molecules without Hs are used
            fragment1 = Chem.RemoveHs(fragment1)
            
            subpocket2 = val[1].split("_")[0]
            fragment2_index = int(val[1].split("_")[1])
            fragment2 = fragment_library[subpocket2]["ROMol_original"][fragment2_index] 
            #remove Hs before finding bonds
            fragment2 = Chem.RemoveHs(fragment2)
            
            #i = 0
            bond1_id = None
            bond2_id = None
        
            
            data1 = data[subpocket1][fragment1_index] #get corresponding connection to load environment, bond type and neighboring subpocket
            for i in range(0,len(data1.ports)):
                environment1 = data1.ports[i].environment
                bond_type1 = data1.ports[i].bond_type
                neighbor1 = data1.ports[i].neighboring_subpocket
                
                data2 = data[subpocket2][fragment2_index] #for matching fragment also get the connection data
                for j in range(0,len(data2.ports)):
                    environment2 = data2.ports[j].environment
                    bond_type2 = data2.ports[j].bond_type
                    neighbor2 = data2.ports[j].neighboring_subpocket
                    
                    #check again if BRICS bond, bond types and subpockets are matching for a connection
                    if  filters.brics_rules.is_brics_bond(environment1, environment2) and bond_type1 == bond_type2 and subpocket2 == neighbor1 and subpocket1 == neighbor2:
                        #get atom indices where connection is build
                        for atom in fragment1.GetAtoms():
                            atom_symbol = atom.GetSymbol()
                            if atom_symbol == "*":
                                bond1_id = subpocket1 + "_" + str(atom.GetIdx())
                        
                        for atom2 in fragment2.GetAtoms():
                            atom_symbol2 = atom2.GetSymbol()
                            if atom_symbol2 == "*":
                                bond2_id = subpocket2 + "_" + str(atom2.GetIdx())
                        
            bond.append([bond1_id, bond2_id, bond_type1]) #save atom indices and bond type for building the connection
        bonds.append(bond)
    return bonds

# %%
bonds = get_bonds(valids, res, fragment_library)

# %%
def construct_ligand(fragment_ids, bond_ids, fragment_library):
    """
    *copied and adapted from kinase_focused_fragment_library*
    Construct a ligand by connecting multiple fragments based on a Combination object
    Parameters
    ----------
    fragment_ids: list of str
        Fragment IDs of recombined ligand, e.g. `["SE_2", "AP_0", "FP_2"]` (`<subpocket>_<fragment index in subpocket pool>`).
    bond_ids : list of list of str
        Bond IDs of recombined ligand, e.g. `[["FP_6", "AP_10"], ["AP_11", "SE_13"]]`: Atom (`<subpocket>_<atom ID>`) pairs per fragment bond.
    fragment_library : dict of pandas.DataFrame
        SMILES and RDKit molecules for fragments (values) per subpocket (key).
    Returns
    -------
    ligand: rdkit.Chem.rdchem.Mol or None
        Recombined ligand (or None if the ligand could not be constructed)
    """

    fragments = []
    for fragment_id in fragment_ids:

        # Get subpocket and fragment index in subpocket
        subpocket = fragment_id.split("_")[0]
        fragment_index = int(fragment_id.split("_")[1])
        fragment = fragment_library[subpocket].ROMol_original[fragment_index]

        # Store unique atom identifiers in original molecule (important for recombined ligand construction based on atom IDs)
        fragment = Chem.RemoveHs(fragment)
        for i, atom in enumerate(fragment.GetAtoms()):
            fragment_atom_id = f"{subpocket}_{i}"
            atom.SetProp("fragment_atom_id", fragment_atom_id)
            atom.SetProp("fragment_id", fragment.GetProp("complex_pdb"))
        fragment = PropertyMol(fragment)

        # Append fragment to list of fragments
        fragments.append(fragment)

    # Combine fragments using map-reduce model
    combo = reduce(Chem.CombineMols, fragments)

    bonds_matching = True
    ed_combo = Chem.EditableMol(combo)
    replaced_dummies = []

    #atoms = combo.GetAtoms()
    
    
    #for bond in bond_ids:

    dummy_1 = next(
            atom for atom in combo.GetAtoms() if atom.GetProp("fragment_atom_id") == bond_ids[0]
    )
    dummy_2 = next(
            atom for atom in combo.GetAtoms() if atom.GetProp("fragment_atom_id") == bond_ids[1]
    )
    atom_1 = dummy_1.GetNeighbors()[0]
    atom_2 = dummy_2.GetNeighbors()[0]

    # check bond types
    bond_type_1 = combo.GetBondBetweenAtoms(dummy_1.GetIdx(), atom_1.GetIdx()).GetBondType()
    bond_type_2 = combo.GetBondBetweenAtoms(dummy_2.GetIdx(), atom_2.GetIdx()).GetBondType()
    if bond_type_1 != bond_type_2:
        bonds_matching = False
        print("Bonds not matching")

    ed_combo.AddBond(atom_1.GetIdx(), atom_2.GetIdx(), order=bond_type_1)

    replaced_dummies.extend([dummy_1.GetIdx(), dummy_2.GetIdx()])

    # Do not construct this ligand if bond types are not matching
    if not bonds_matching:
        return

    # Remove replaced dummy atoms
    replaced_dummies.sort(reverse=True)
    for dummy in replaced_dummies:
        ed_combo.RemoveAtom(dummy)

    ligand = ed_combo.GetMol()

    # Replace remaining dummy atoms with hydrogens
    du = Chem.MolFromSmiles("*")
    h = Chem.MolFromSmiles("[H]", sanitize=False)
    ligand = AllChem.ReplaceSubstructs(ligand, du, h, replaceAll=True)[0]
    try:
        ligand = Chem.RemoveHs(ligand)
    except ValueError:
        print(Chem.MolToSmiles(ligand))
        return

    # Clear properties
    for prop in ligand.GetPropNames():
        ligand.ClearProp(prop)
    for atom in ligand.GetAtoms():
        atom.ClearProp("fragment_atom_id")

    # Generate 2D coordinates
    AllChem.Compute2DCoords(ligand)

    return ligand

# %%
def get_pairs(valids, bonds, fragment_library_filtered):
    pairs = []
    frags1 = []
    frags2 = []
    ids = []
    for i in range(0, len(valids)):
        for j in range(0, len(valids[i])):
            frag1 = fragment_library_filtered[valids[i][j][0].split("_")[0]]['ROMol_dummy'][int(valids[i][j][0].split("_")[1])]
            frag2 = fragment_library_filtered[valids[i][j][1].split("_")[0]]['ROMol_dummy'][int(valids[i][j][1].split("_")[1])]
            
            frags1.append(frag1)
            frags2.append(frag2)
            
            pair = construct_ligand(valids[i][j], bonds[i][j], fragment_library_filtered)
            pairs.append(pair)
            ids.append(valids[i][j])
            
    return pd.DataFrame({'fragment ids': ids, 'fragment1':frags1, 'fragment2':frags2, 'pair':pairs})

# %%
from rdkit.Chem.PropertyMol import PropertyMol
from functools import reduce

# %%
pair_df = get_pairs(valids, bonds, fragment_library)

# %%
pair_smiles = []
for pair in pair_df['pair']:
    pair_smiles.append(Chem.MolToSmiles(pair))
    
unique_smiles = pd.DataFrame({'pair': pair_smiles})['pair'].unique()

# %% [markdown]
# # Multiprocessing

# %%
def call_retro_parallel(pair_smiles):
    """
    One step retrosynthesis using ASKCOS for all valid build pairs of fragments.
    Saving the plausibility and the children that can build this pair according to retrosynthetic
    analysis.

    Parameters
    ----------
    pair_smiles : numpy array
        containing SMILES strings of pairs build by fragments

    Returns
    -------
    pandas DataFrame
        containing the pair, the children building this pair and their plausibility

    """
    pairs = []
    children1 = []
    children2 = []
    plausibilities = []
    # n_attempts = 5
    for smile in pair_smiles:
        if smile in open('retro.txt').read():
            print('already requested')
        else:
            print(smile)
            pairs.append(smile)
            cur_children1 = []
            cur_children2 = []
            cur_plausibilities = []
            HOST = "https://askcos.mit.edu/"
            params = {
                "smiles": smile,  # required
                # optional with defaults shown
                "max_depth": 1,  # maximum number of reaction steps
                "max_branching": 25,  # ?max number of branches are looked at to find "best"?
                "expansion_time": 20,  # how long the expansion can run
                "max_ppg": 100,  # maximum price per gram
                "template_count": 100,
                # "max_cum_prob"
                # which common probability reached until no more templates are used
                "max_cum_prob": 0.995,
                # "chemical_property_logic"
                # molecules are buyable or not, can be 'none' (only price relevant),
                # 'and' (price and heavy atoms constraint) or
                # 'or' (one of both constraints is relevant)
                "chemical_property_logic": "none",
                # max heavy atom contraints if 'and' or 'or' is used in 'chemical_property_logic'
                "max_chemprop_c": 0,
                "max_chemprop_n": 0,
                "max_chemprop_o": 0,
                "max_chemprop_h": 0,
                # want to use popular chemicals as reasonable stopping points?
                "chemical_popularity_logic": "none",
                "min_chempop_reactants": 5,  # min frequence as popular reactant
                "min_chempop_products": 5,  # min frequence as popular prouct
                "filter_threshold": 0.75,
                "return_first": "true",  # default is false
            }
            # for attempt in range(n_attempts):
            try:
                resp = requests.get(HOST + "/api/treebuilder/", params=params,
                                    verify=False)
            except requests.exceptions.Timeout as err:
                print(err)
                sleep(50)
                continue
            retro = resp.json()

            if "trees" in retro:
                if (len(retro["trees"])) > 0:
                    for num_tree in range(0, len(retro["trees"])):
                        if len(retro["trees"][num_tree]["children"][0]["children"]) == 2:
                            plausibility = retro["trees"][0]["children"][0]["plausibility"]
                            child1 = retro["trees"][num_tree]["children"][0]["children"][0][
                                "smiles"
                            ]
                            child2 = retro["trees"][num_tree]["children"][0]["children"][1][
                                "smiles"
                            ]
                            cur_children1.append(child1)
                            cur_children2.append(child2)
                            cur_plausibilities.append(plausibility)

                else:
                    cur_children1.append(None)
                    cur_children2.append(None)
                    cur_plausibilities.append(0)
            else:
                cur_children1.append(None)
                cur_children2.append(None)
                cur_plausibilities.append(0)
            children1.append(cur_children1)
            children2.append(cur_children2)
            plausibilities.append(cur_plausibilities)

    res = pd.DataFrame(
        list(zip(pairs, children1, children2, plausibilities)),
        columns=["pair", "child 1", "child 2", "plausibility"],
    )

    return res

# %%
import numpy as np
import requests
import warnings

# %%
 num_cpu = mp.cpu_count()

# %%
df_split = np.array_split(unique_smiles[0:10], num_cpu)

# %%
# manual multiprocessing
# %%time
# warnings.filterwarnings("ignore")
# processes = []

# for i in range(num_cpu):
#     p = mp.Process(target=call_retro_parallel, args=(df_split[i],))
#     p.start()
#     processes.append(p)
    
# for process in processes:
#     process.join()
# Out:
# already requested
# already requestedalready requested
#
# already requestedalready requested
#
# already requested
# already requested
# already requested
# already requested
# already requested
# CPU times: user 0 ns, sys: 438 ms, total: 438 ms
# Wall time: 491 ms

# %%
# df_split = np.array_split(unique_smiles[3000:3100], num_cpu)

# %%
# saves only after iterating through all smiles 
# %%time
# warnings.filterwarnings("ignore")

# df_split = np.array_split(unique_smiles[3000:3100], num_cpu)
# p = mp.Pool(num_cpu)
# with open("retro.txt", "a+") as f_object:
#     for result in p.map(call_retro_parallel, df_split):
#             #save current result in csv file
#         for i, row in result.iterrows():
#             f_object.write(str(row['pair']) + "; " + str(row['child 1']) + "; " + str(row['child 2']) + "; " + str(row['plausibility']) + "\n")
#     p.close()
#     p.join()
#                 # print(row['pair'])
#             # f_object.write(result.to_string())
# f_object.close()
# #result = p.map(call_retro_parallel, df_split)
# Out:
# CN(C)c1ccc(Nc2ccncn2)cc1c1ccc2[nH]c(Nc3ccncn3)nc2c1Cn1cc(Nc2ccncn2)c(C(F)(F)F)n1CC(C)(C)c1ccc(Nc2ccncn2)cc1FC(F)(F)c1cccc(Nc2ncc(Br)cn2)c1CCc1cccc(Nc2ccncn2)n1OCCn1cc(Nc2ncc(Br)cn2)cn1
#
#
#
#
#
#
# Cc1ccc(Cl)c(Nc2ncc(Br)cn2)c1
# Cc1ccc(Nc2ccncn2)nc1C
# c1ccc2ncc(Nc3ccncn3)cc2c1
# Clc1cccc(Nc2ncc(Br)cn2)c1Cl
# COc1ccc2cccc(Nc3ccncn3)c2c1
# Brc1cnc(Nc2cccnc2)nc1
# Clc1ncc(Nc2ccncn2)cn1
# NC(=O)c1ccc(Nc2ccncn2)cc1
# O=C(Nc1cccc(Nc2ncc(Br)cn2)c1)c1ccccc1
# Cc1cc(Nc2ccncn2)nc(N)n1
# Brc1cnc(NNCc2cccnc2)nc1
# c1cc(Nc2cncnc2)ncn1
# Fc1ccccc1Nc1ncc(Br)cn1
# Brc1cnc(Nc2ccc3c(c2)CCC3)nc1
# O=C1CCCN1c1cccc(Nc2ccncn2)c1
# CSc1cccc(Nc2ccncn2)c1
# Brc1ccc(Nc2ccncn2)cc1
# Clc1ccccc1Nc1ncc(Br)cn1
# Oc1ccc2cccc(Nc3ccncn3)c2c1
# OCCc1ccc(Nc2ccncn2)cc1
# c1cnc(NNc2ccncn2)nc1
# O[C@@H]1CC[C@@H](Nc2ccncn2)CC1
# Brc1cnc(Nc2ccccc2Br)nc1
# COc1cc(F)c(Nc2ccncn2)cc1OC
# Cc1ncc(Nc2ncc(Br)cn2)[nH]1
# Cc1ccc(Nc2ncc(Br)cn2)c(Br)c1
# O=C(Nc1ccccc1)c1ccc(Nc2ccncn2)cc1
# COc1ccc(Cl)cc1Nc1ccncn1
# COc1cc(Nc2ccncn2)ccc1Cl
# CC[C@@H](CO)Nc1ccncn1
# COc1cc(N2CCNCC2)ccc1Nc1ccncn1
# c1ccc2c(CNc3ccncn3)nccc2c1
# N#Cc1ccccc1Nc1ncc(Br)cn1
# Nc1nccc(Nc2ncc(Br)cn2)n1
# Brc1cnc(Nc2cnco2)nc1
# Fc1ccc(Nc2ccncn2)c(Cl)c1
# Cc1ccc(Nc2ccncn2)o1
# c1cc(Nc2cn[nH]c2)ncn1
# Fc1cccc(Nc2ccncn2)c1
# FC(F)(F)Oc1ccccc1Nc1ncc(Br)cn1
# O[C@@H]1CC[C@H](Nc2ccncn2)C1
# CS(=O)(=O)c1ccc(Cl)c(Nc2ccncn2)c1
# COc1cccc(Nc2ncc(Br)cn2)c1
# Clc1ccc(Nc2ccncn2)cc1
# Brc1cnc(Nc2cnc3ccccn23)nc1
# c1c[nH]c(Nc2ccncn2)c1
# CNC(=O)c1ccccc1Nc1ncc(Br)cn1
# COc1cc(Nc2ccncn2)c(OC)cc1Br
# NC(=O)c1ccccc1Nc1ncc(Br)cn1
# Brc1cnc(Nc2ccncn2)nc1
# Cc1nc(C)c(Nc2ncc(Br)cn2)s1
# OCCCNc1ccncn1
# COc1cc(Nc2ccncn2)cc(OC)c1
# CCOc1ccccc1Nc1ncc(Br)cn1
# Brc1cnc(Nc2ccc3ccccc3c2)nc1
# COc1ccc(Nc2ccncn2)cc1OC
# Cc1nc(N)sc1Nc1ncc(Br)cn1
# c1cc(Nc2ccc3c(c2)CCO3)ncn1
# c1cc(Nc2ccc3cn[nH]c3c2)ncn1
# O[C@H]1C[C@@H](Nc2ncc(Br)cn2)C1
# Brc1cnc(Nc2cnn(Cc3ccccc3)c2)nc1
# OCCOc1ccc(Nc2ccncn2)cc1
# CCc1ccc(Nc2ccncn2)cc1
# Brc1cnc(Nc2cnc3cccnn23)nc1
# Clc1ccc(Nc2ncc(Br)cn2)s1
# c1ccc2cc(Nc3ccncn3)ncc2c1
# c1ccc2oc(Nc3ccncn3)cc2c1
# Fc1cc(F)cc(CNc2ncc(Br)cn2)c1
# Fc1cccc(F)c1Nc1ncc(Br)cn1
# Clc1ccc(Nc2ccncn2)c(Cl)c1
# c1cc(Nc2ccncn2)cc(C2CCNCC2)c1
# COc1cc(Nc2ccncn2)ccc1O
# Clc1cccc(Cl)c1Nc1ncc(Br)cn1
# Brc1cnc(NNc2cccnc2)nc1
# Brc1cnc(Nc2ccnc3ccccc23)nc1
# CNC(=O)c1ccc(Nc2ccncn2)cc1
# Brc1cnc(Nc2cnc(-c3ccccc3)[nH]2)nc1
# c1cc(Nc2ccsc2)ncn1
# Cc1cc(Nc2ccncn2)nn1C
# CC(C)(C)NNc1ncc(Br)cn1
# c1cc(Nc2ccncn2)c2c(c1)OCO2
# FC(F)(F)Oc1ccc(Nc2ccncn2)cc1
# C[C@H](CO)NNc1ncc(Br)cn1
# Brc1cnc(Nc2cc[nH]n2)nc1
# C[C@H](O)COc1ccc(Nc2ccncn2)cc1
# c1cc(Nc2cscn2)ncn1
# N[C@H](Nc1ncc(Br)cn1)c1ccco1
# c1cc(Nc2scc3c2OCCO3)ncn1
# Brc1cnc(NOC2CCCCC2)nc1
# FC(F)(F)c1ccc(Nc2ccncn2)cc1
# Brc1cnc(Nn2cnc3ccccc32)nc1
# Fc1ccc(Nc2ccncn2)cc1F
# CC(C)CONc1ncc(Br)cn1
# CPU times: user 391 ms, sys: 938 ms, total: 1.33 s
# Wall time: 8min 27s

# %%
# %%time
# warnings.filterwarnings("ignore")
# df_split1 = np.array_split(unique_smiles, 100)
# p = mp.Pool(num_cpu)
# with open("retro.txt", "a+") as f_object:
#     for split in df_split1:
#         df_split = np.array_split(split, num_cpu)
#         for result in p.map(call_retro_parallel, df_split):
#                 #save current result in csv file
#             for i, row in result.iterrows():
#                 f_object.write(str(row['pair']) + "; " + str(row['child 1']) + "; " + str(row['child 2']) + "; " + str(row['plausibility']) + "\n")
#     p.close()
#     p.join()
# f_object.close()
# Out:
# already requestedalready requestedalready requestedalready requestedalready requestedalready requestedalready requested
#
# already requested
#
#
# already requested
#
# already requestedalready requested
# already requested
# already requested
# already requestedalready requested
# already requestedalready requested
#
#
# already requested
#
#
#
# already requestedalready requestedalready requestedalready requestedalready requestedalready requestedalready requested
#
# already requested
#
#
#
#
#
# already requestedalready requestedalready requestedalready requestedalready requestedalready requestedalready requestedalready requested
#
#
#
#
#
#
#
# already requestedalready requestedalready requested
# already requestedalready requestedalready requested
# already requestedalready requested
#
# already requested
#
#
# already requested
# already requestedalready requested
# already requestedalready requestedalready requested
# already requested
#
# already requestedalready requested
#
#
# already requested
# already requested
#
#
# already requestedalready requestedalready requestedalready requestedalready requested
#
# already requestedalready requested
#
#
#
# already requestedalready requested
#
# already requestedalready requested
# already requestedalready requestedalready requestedalready requested
#
# already requested
#
#
#
# already requestedalready requested
#
# already requestedalready requested
#
# already requestedalready requested

# %%
# %%time
warnings.filterwarnings("ignore")
# filter out smiles that are already requested
filtered_smiles = []
for smiles in unique_smiles:
    if not smiles in open('retro.txt').read():
        filtered_smiles.append(smiles)
print(len(filtered_smiles))
df_split1 = np.array_split(filtered_smiles, 150)
p = mp.Pool(num_cpu)
for split in df_split1:
    with open("retro.txt", "a+") as f_object:
        df_split = np.array_split(split, num_cpu)
        for result in p.map(call_retro_parallel, df_split):
                #save current result in csv file
            # print(result)
            for i, row in result.iterrows():
                f_object.write(str(row['pair']) + "; " + str(row['child 1']) + "; " + str(row['child 2']) + "; " + str(row['plausibility']) + "\n")
    f_object.close()
p.close()
p.join()
# Out:
# 13083
# Nc1cc(-c2ccc(OC(F)(F)F)cc2)[nH]n1Nc1cc(-c2ccc3c(c2)CCO3)[nH]n1CSc1cccc(-c2cc(N)n[nH]2)c1Cc1cc(C)cc(-c2cc(N)n[nH]2)c1CNS(=O)(=O)c1ccc(-c2cc(N)n[nH]2)cc1Nc1cc(-c2ccc(Cl)c(O)c2)[nH]n1N#Cc1cnc(-c2cc(N)n[nH]2)cn1Nc1cc(-c2ccncn2)[nH]n1
#
#
#
#
#
#
#
# Nc1cc(-c2n[nH]c3ccccc23)[nH]n1
# COc1ccc2cccc(-c3cc(N)n[nH]3)c2c1
# Nc1cc(-c2cnccn2)[nH]n1
# Nc1cc(-c2cscn2)[nH]n1
# Nc1cc(-c2cc3ccccc3cn2)[nH]n1
# Nc1cc(-c2ccc(C(F)(F)F)cc2)[nH]n1
# Nc1cc([C@@H]2CC[C@@H](O)CC2)[nH]n1
# Nc1cc(-c2c(F)cccc2F)[nH]n1
# Nc1cc(COc2ccccc2Cl)[nH]n1
# Nc1cc(-c2cccc3ccc(O)cc23)[nH]n1
# CCc1cccc(-c2cc(N)n[nH]2)n1
# COC(=O)c1ccc(-c2cc(N)n[nH]2)o1
# CC[C@@H](CO)c1cc(N)n[nH]1
# CC(=O)Nc1cccc(-c2cc(N)n[nH]2)c1
# CN(C)c1ccc(-c2cc(N)n[nH]2)cc1
# COc1cc(F)c(-c2cc(N)n[nH]2)cc1OC
# Nc1cc(-c2c(Cl)cccc2Cl)[nH]n1
# Nc1cc(-c2ccc(F)c(Cl)c2)[nH]n1
# Nc1cc(-c2ccc(F)cc2Cl)[nH]n1
# Cc1ccc(-c2cc(N)n[nH]2)nc1C
# COc1cc(-c2cc(N)n[nH]2)ccc1O
# Nc1cc(-c2ccoc2)[nH]n1
# COc1cc(-c2cc(N)n[nH]2)ccc1Cl
# Nc1cc(Oc2ccc(F)cc2)[nH]n1
# Cc1nc(C)c(-c2cc(N)n[nH]2)s1
# Nc1cc([C@H]2CC[C@@H](O)C2)[nH]n1
# Nc1cc(-c2cccc(N3CCCC3=O)c2)[nH]n1
# Nc1cc([C@H](CO)c2ccccc2)[nH]n1
# COc1cc(CCc2cc(N)n[nH]2)ccc1O
# Cc1ccc(-c2cc(N)n[nH]2)o1
# Nc1cc(-c2cccc3c2OCO3)[nH]n1
# Nc1cc(-c2cnc(Cl)nc2)[nH]n1
# Nc1cc(-c2ncc(Br)cn2)[nH]n1
# Cc1ccc(O)cc1-c1cc(N)n[nH]1
# Nc1cc(-c2ccc(O)cc2Cl)[nH]n1
# N#Cc1ccc(-c2cc(N)n[nH]2)cn1
# Nc1cc(-c2scc3c2OCCO3)[nH]n1
# Nc1cc(-c2ccc(CCO)cc2)[nH]n1
# Nc1cc(-c2cncnc2)[nH]n1
# COc1cc(-c2cc(N)n[nH]2)c(OC)cc1Br
# Cc1ccc(-c2cc(N)n[nH]2)cc1C
# Cc1ncc(-c2cc(N)n[nH]2)[nH]1
# Nc1cc(-c2ccc(F)c(F)c2)[nH]n1
# COc1ccc(-c2cc(N)n[nH]2)cc1OC
# COc1cc(N2CCNCC2)ccc1-c1cc(N)n[nH]1
# Nc1cc(-c2cc(O)ccc2Cl)[nH]n1
# COc1cc(OC)cc(-c2cc(N)n[nH]2)c1
# CC(C)(C)c1ccc(-c2cc(N)n[nH]2)cc1
# Nc1cc(COc2cccc(Cl)c2)[nH]n1
# CCc1ccc(-c2cc(N)n[nH]2)cc1
# Cc1ccc(CO)cc1-c1cc(N)n[nH]1
# Nc1cc(-c2ccc(Br)cc2)[nH]n1
# Nc1cc(-c2ccc3cn[nH]c3c2)[nH]n1
# Nc1cc(-c2ccnc(N)n2)[nH]n1
# Nc1cc(-c2ccc(Cl)cc2Cl)[nH]n1
# Nc1cc(-c2cccc(Br)c2)[nH]n1
# COc1ccc(Cl)cc1-c1cc(N)n[nH]1
# CS(=O)(=O)c1ccc(Cl)c(-c2cc(N)n[nH]2)c1
# Nc1cc(-c2cc3ccccc3o2)[nH]n1
# Nc1cc(-c2cnc3ccccc3c2)[nH]n1
# Nc1cc(-c2cccs2)[nH]n1
# Nc1cc(-c2ccsc2)[nH]n1
# Nc1cc(-c2cnc(O)c(Cl)c2)[nH]n1
# Nc1cc(-c2ccc(O)cc2)[nH]n1
# Nc1cc([C@@H]2C[C@H](O)C2)[nH]n1
# CNC(=O)c1ccc(-c2cc(N)n[nH]2)cc1
# Nc1cc(-c2ccc(O)cc2O)[nH]n1
# Nc1cc(-c2cn[nH]c2)[nH]n1
# Nc1cc(-c2ccncc2)[nH]n1
# Cn1cc(-c2cc(N)n[nH]2)c(C(F)(F)F)n1
# Nc1cc(-c2ccco2)[nH]n1
# Nc1cc(-c2ccccc2Cl)[nH]n1
# Nc1cc(-c2c[nH]c3ccccc23)[nH]n1
# Nc1cc(Cn2ccccc2=O)[nH]n1
# COC(=O)c1ccc(Cl)c(-c2cc(N)n[nH]2)c1
# Cc1cc(-c2cc(N)n[nH]2)nc(N)n1
# Nc1cc(-c2ccc[nH]2)[nH]n1
# Nc1cc(-c2cccc3ncccc23)[nH]n1
# Cc1nc2ccc(-c3cc(N)n[nH]3)cc2[nH]1
# Nc1cc(-c2cc[nH]c2)[nH]n1
# Cc1cc(Nc2nccs2)nc(N)n1NC(=O)Nc1ccc(-c2cc(N)n[nH]2)cc1Nc1cc(-c2cc(O)cc(Br)c2)[nH]n1c1ccc2[nH]c(Nc3nccs3)nc2c1c1c[nH]c(Nc2nccs2)c1CCOc1ccc(Nc2nccs2)cc1C[C@H](O)COc1ccc(Nc2nccs2)cc1CCc1sccc1-c1cc(N)n[nH]1
#
#
#
#
#
#
#
# CSc1cccc(Nc2nccs2)c1
# c1csc(Nc2ccc3c(c2)CCO3)n1
# CS(=O)(=O)c1ccc(-c2cc(N)n[nH]2)cc1
# NC(=O)c1ccc(Nc2nccs2)cc1
# Nc1cc(-c2cc(Cl)c(O)c(Cl)c2)[nH]n1
# CNS(=O)(=O)c1ccc(Nc2nccs2)cc1
# Cc1n[nH]cc1Nc1nccs1
# O[C@@H]1CC[C@@H](Nc2nccs2)CC1
# c1cnc(NNc2nccs2)nc1
# c1ccc2cc(Nc3nccs3)ncc2c1
# Nc1cc(-c2cnco2)[nH]n1
# COc1ncccc1Nc1nccs1
# Nc1cc(-c2nccs2)[nH]n1
# Nc1cc(-c2nc3ccccc3s2)[nH]n1
# CC[C@@H](CO)Nc1nccs1
# FC(F)(F)c1ccc(Nc2nccs2)cc1
# CC(=O)Nc1cccc(Nc2nccs2)c1
# Cc1nc2ccc(-c3cc(N)n[nH]3)cc2o1
# Nc1cc(-c2ccc3c(c2)CCN3)[nH]n1
# O=C(Nc1ccccc1)c1ccc(Nc2nccs2)cc1
# CS(=O)(=O)c1cccc(Nc2nccs2)c1
# Nc1cc(-c2cncc(O)c2)[nH]n1
# Fc1ccc(Nc2nccs2)c(Cl)c1
# CN(C)c1ccc(Nc2nccs2)cc1
# COc1cc(Nc2nccs2)ccc1O
# c1ccc2c(CNc3nccs3)nccc2c1
# Nc1cc(-c2cc(F)c(O)c(F)c2)[nH]n1
# Nc1cc(-c2cc(N)n[nH]2)[nH]n1
# O[C@@H]1CC[C@H](Nc2nccs2)C1
# Cn1nncc1Nc1nccs1
# Cc1nc(C)c(Nc2nccs2)s1
# Fc1cccc(Nc2nccs2)c1
# Nc1cc(-c2ccc3c(c2)CC(=O)N3)[nH]n1
# c1cc(Nc2nccs2)c2c(c1)OCO2
# Nc1cc(-c2ccc3c(=O)[nH][nH]c3c2)[nH]n1
# Brc1cnc(Nc2nccs2)nc1
# Nc1cc(-c2ccc3[nH]c(=O)[nH]c3c2)[nH]n1
# Clc1ccc(Nc2nccs2)cc1
# COc1cc(Nc2nccs2)cc(OC)c1OC
# Clc1ncc(Nc2nccs2)cn1
# Nc1cc(OCc2ccccc2)[nH]n1
# c1csc(Nc2scc3c2OCCO3)n1
# NC(=O)[C@H]1CC[C@@H](c2cc(N)n[nH]2)CC1
# OCCCNc1nccs1
# COc1ccc(Nc2nccs2)cc1OC
# Cn1cc(Nc2nccs2)cn1
# Nc1cc(Oc2ccc(F)cc2F)[nH]n1
# Cn1ncc(N)c1-c1cc(N)n[nH]1
# OCCOc1ccc(Nc2nccs2)cc1
# Fc1ccc(Nc2nccs2)cc1F
# c1ncc(Nc2nccs2)cn1
# CCc1ccc(Nc2nccs2)cc1
# Nc1cc(Nc2ccncc2)[nH]n1
# Nc1cc(Oc2ccccc2F)[nH]n1
# CC(C)(C)c1ccc(Nc2nccs2)cc1
# C[C@H](CC(N)=O)c1cc(N)n[nH]1
# Brc1ccc(Nc2nccs2)cc1
# Cc1nn(C)cc1Nc1nccs1
# Nc1cc(-c2ccc(Br)cc2F)[nH]n1
# c1cc(Nc2nccs2)cc(C2CCNCC2)c1
# Clc1ccc(Nc2nccs2)c(Cl)c1
# Nc1cc(Cc2ccc(F)cc2)[nH]n1
# COc1ccc(Cl)cc1Nc1nccs1
# c1ccc2ncc(Nc3nccs3)cc2c1
# Cc1cc(Nc2nccs2)nn1C
# c1cnn2c(Nc3nccs3)cnc2c1
# CCc1cc(O)ccc1-c1cc(N)n[nH]1
# Cc1csc(-c2cc(N)n[nH]2)n1
# c1csc(Nc2ccsc2)n1
# c1csc(Nc2cn[nH]c2)n1
# Oc1cccc(Nc2nccs2)c1
# c1coc(Nc2nccs2)c1
# Nc1cc(NCc2c(F)cccc2Cl)[nH]n1
# Cc1cc(O)ccc1-c1cc(N)n[nH]1
# c1ccc2c(Nc3nccs3)c[nH]c2c1
# Cc1ccc(-c2cc(N)n[nH]2)c(C)n1
# COc1ccc(Nc2nccs2)cc1
# N#Cc1ccc(Nc2nccs2)cc1
# Cc1cccc(C)c1-c1cc(N)n[nH]1
# Nc1cc(-n2ccnc2)[nH]n1
# CNC(=O)c1ccc(Nc2nccs2)cc1Cn1cc(Nc2nccs2)c(C(F)(F)F)n1c1ccc(Cn2cc(Cc3ccc4c(c3)OCO4)cn2)cc1Cc1nc(N)sc1Cc1ccc2c(c1)OCO2O[C@H]1C[C@@H](Cc2ccc3c(c2)OCO3)C1COc1ccc(Cc2ccc3c(c2)OCO3)cc1Clc1ccc2c(Cc3ccc4c(c3)OCO4)cncc2c1N#C[C@H]1CC[C@H](Cc2ccc3c(c2)OCO3)CC1
#
#
#
#
#
#
#
# Cc1cc(Cc2ccc3c(c2)OCO3)no1
# c1cnn2c(Cc3ccc4c(c3)OCO4)cnc2c1
# Cc1cc(C)cc(Nc2nccs2)c1
# Oc1cccc(Cc2ccc3c(c2)OCO3)c1
# FC(F)(F)Oc1ccc(Nc2nccs2)cc1
# c1ccc2c(Cc3ccc4c(c3)OCO4)ccnc2c1
# N#CC[C@@H]1CC[C@@H](Cc2ccc3c(c2)OCO3)CC1
# Fc1cccc(F)c1Cc1ccc2c(c1)OCO2
# COc1ccc2cccc(Nc3nccs3)c2c1
# c1cc2c(cc1Cc1cnoc1)OCO2
# c1cc(Cc2ccc3c(c2)OCO3)n[nH]1
# Clc1cccc(Cl)c1Cc1ccc2c(c1)OCO2
# c1csc(Nc2cscn2)n1
# OCc1cccc(Cc2ccc3c(c2)OCO3)c1
# c1ccc(-c2ncc(Cc3ccc4c(c3)OCO4)[nH]2)cc1
# N#C[C@H]1CCOC[C@@H]1Cc1ccc2c(c1)OCO2
# Oc1ccc2cccc(Nc3nccs3)c2c1
# FC(F)(F)c1cccc(Cc2ccc3c(c2)OCO3)c1
# Cc1ccc(Cl)c(Cc2ccc3c(c2)OCO3)c1
# CCCn1cc(Cc2ccc3c(c2)OCO3)cn1
# CCc1cccc(Nc2nccs2)n1
# Cn1cncc1Cc1ccc2c(c1)OCO2
# COc1cc(F)c(Nc2nccs2)cc1OC
# c1cc(Cc2ccc3c(c2)OCO3)ncn1
# c1cncc(Cc2ccc3c(c2)OCO3)c1
# CC(C)(C)NS(=O)(=O)c1ccc(Cc2ccc3c(c2)OCO3)cc1
# Cc1ccc(Nc2nccs2)nc1C
# Clc1cccc(Cc2ccc3c(c2)OCO3)c1Cl
# O=C1CCc2cccc(Cc3ccc4c(c3)OCO4)c21
# OCCn1cc(Cc2ccc3c(c2)OCO3)cn1
# c1csc(Cc2ccc3c(c2)OCO3)c1
# O=C1CCCN1c1cccc(Nc2nccs2)c1
# COc1cc(Nc2nccs2)ccc1Cl
# CNS(=O)(=O)c1ccc(Cc2ccc3c(c2)OCO3)cc1
# Fc1ccccc1Cc1ccc2c(c1)OCO2
# Cc1ncc(Cc2ccc3c(c2)OCO3)[nH]1
# c1coc(Cc2ccc3c(c2)OCO3)c1
# O=C(Nc1cccc(Cc2ccc3c(c2)OCO3)c1)c1ccccc1
# CC(C)(N)c1ccc(Cc2ccc3c(c2)OCO3)cc1
# Cc1ccc(Nc2nccs2)o1
# OCCc1ccc(Nc2nccs2)cc1
# Clc1ccccc1Cc1ccc2c(c1)OCO2
# CS(=O)(=O)c1ccc(Cc2ccc3c(c2)OCO3)cc1
# Nc1nccc(Cc2ccc3c(c2)OCO3)n1
# c1cc2c(cc1Cc1ccc3c(c1)OCO3)CCC2
# Cn1cc(Cc2ccc3c(c2)OCO3)cn1
# C[S@](=O)c1ccc(Cc2ccc3c(c2)OCO3)cc1
# Brc1ccccc1Cc1ccc2c(c1)OCO2
# COc1cc(N2CCNCC2)ccc1Nc1nccs1
# COc1cc(Nc2nccs2)c(OC)cc1Br
# NC(=O)c1c(F)cccc1Cc1ccc2c(c1)OCO2
# Cc1ccc(Cc2ccc3c(c2)OCO3)c(Br)c1
# COc1cccc(Cc2ccc3c(c2)OCO3)c1
# N#Cc1ccccc1Cc1ccc2c(c1)OCO2
# N#CCCc1cccc(Cc2ccc3c(c2)OCO3)c1
# O=c1[nH]ccc2oc(Cc3ccc4c(c3)OCO4)cc12
# c1ccc2c(c1)cnn2Cc1ccc2c(c1)OCO2
# already requested
# c1csc(Nc2ccc3cn[nH]c3c2)n1
# CS(=O)(=O)c1ccc(Cl)c(Nc2nccs2)c1
# FC(F)(F)Oc1ccccc1Cc1ccc2c(c1)OCO2
# c1ccc2cc(Cc3ccc4c(c3)OCO4)ccc2c1
# Oc1cccc2c1cnn2Cc1ccc2c(c1)OCO2
# c1ncc(Cc2ccc3c(c2)OCO3)o1
# c1ccc2c(Cc3ccc4c(c3)OCO4)c[nH]c2c1
# NC(=O)c1ccccc1Cc1ccc2c(c1)OCO2
# CCC(=O)Nc1ccc(Cc2ccc3c(c2)OCO3)cc1
# c1ccc2oc(Nc3nccs3)cc2c1
# CNC(=O)c1ccccc1Cc1ccc2c(c1)OCO2
# Clc1ccc(Cc2ccc3c(c2)OCO3)s1
# c1cc2c(Cc3ccc4c(c3)OCO4)c[nH]c2cn1
# c1ccn2c(Cc3ccc4c(c3)OCO4)cnc2c1
# Fc1ccc(Cc2ccc3c(c2)OCO3)c(C(F)(F)F)c1
# Oc1ncccc1Cc1ccc2c(c1)OCO2
# c1ccc2c(c1)ncn2Cc1ccc2c(c1)OCO2
# N#CCC(=O)N1CCC[C@@H](Cc2ccc3c(c2)OCO3)C1
# CC(=O)Nc1cccc(Cc2ccc3c(c2)OCO3)c1
# CCOc1ccccc1Cc1ccc2c(c1)OCO2
# Oc1ccc2nc(Cc3ccc4c(c3)OCO4)[nH]c2c1
# Cc1nc(C)c(Cc2ccc3c(c2)OCO3)s1
# C[C@H](CO)Nc1ccc2c(c1)OCO2C[C@@]1(O)CC[C@H](Cc2ccc3c(c2)OCO3)CC1c1cncc(-c2ccc3c(c2)OCO3)c1N[C@H](c1ccc2c(c1)OCO2)c1ccco1c1coc(-c2ccc3c(c2)OCO3)c1COc1ccc(Cc2ccc3c(c2)OCO3)c(OC)c1CC(C)(C)Nc1ccc2c(c1)OCO2CCCn1cc(-c2ccc3c(c2)OCO3)cn1
#
#
#
#
#
#
#
# c1ccc2c(c1)ncn2-c1ccc2c(c1)OCO2
# Fc1ccccc1-c1ccc2c(c1)OCO2
# Cn1cc(-c2ccc3c(c2)OCO3)cn1
# O=C1CCc2cccc(-c3ccc4c(c3)OCO4)c21
# COc1ccc(OC)c(Cc2ccc3c(c2)OCO3)c1
# OCCn1cc(-c2ccc3c(c2)OCO3)cn1
# c1cc2c(cc1OC1CCCCC1)OCO2
# CC(C)COc1ccc2c(c1)OCO2
# O=C(c1ccccc1)c1ccc(Cc2ccc3c(c2)OCO3)cc1
# CC(C)(N)c1ccc(-c2ccc3c(c2)OCO3)cc1
# Clc1ccccc1-c1ccc2c(c1)OCO2
# CC(C)Nc1ccc2c(c1)OCO2
# Cc1ccc(Cl)c(-c2ccc3c(c2)OCO3)c1
# O=C(Nc1cccc(-c2ccc3c(c2)OCO3)c1)c1ccccc1
# CCOC(=O)Cc1ccc2c(c1)OCO2
# Cc1cc(C)cc(Cc2ccc3c(c2)OCO3)c1
# O=C(Nc1ccc2c(c1)OCO2)c1cccs1
# Clc1cccc(-c2ccc3c(c2)OCO3)c1Cl
# c1cn(Cc2ccc3c(c2)OCO3)cn1
# Brc1ccccc1-c1ccc2c(c1)OCO2
# N#CCCc1cccc(-c2ccc3c(c2)OCO3)c1
# c1ccc2[nH]c(C3CCN(Cc4ccc5c(c4)OCO5)CC3)nc2c1
# C[S@](=O)c1ccc(-c2ccc3c(c2)OCO3)cc1
# c1cc2c(cc1-c1ccc3c(c1)OCO3)CCC2
# c1cncc(CNc2ccc3c(c2)OCO3)c1
# Nc1ncc(Cc2ccc3c(c2)OCO3)s1
# C[C@@H](O)[C@@H](C)Oc1ccc2c(c1)OCO2
# N#Cc1ccccc1-c1ccc2c(c1)OCO2
# CNC(=O)c1ccccc1-c1ccc2c(c1)OCO2
# Cc1ncc(-c2ccc3c(c2)OCO3)[nH]1
# CCN(CC)c1ccc2c(c1)OCO2
# CCC(=O)Nc1ccc(-c2ccc3c(c2)OCO3)cc1
# Cc1ccc(-c2ccc3c(c2)OCO3)c(Br)c1
# FC(F)(F)Oc1ccccc1-c1ccc2c(c1)OCO2
# c1ccc2c(-c3ccc4c(c3)OCO4)cncc2c1
# Nc1nnc(Cc2ccc3c(c2)OCO3)s1
# O=c1[nH]ccc2oc(-c3ccc4c(c3)OCO4)cc12
# CCOc1ccccc1-c1ccc2c(c1)OCO2
# Nc1nccc(-c2ccc3c(c2)OCO3)n1
# NC(=O)c1ccccc1-c1ccc2c(c1)OCO2
# c1ncc(-c2ccc3c(c2)OCO3)o1
# Cc1cncc(Cc2ccc3c(c2)OCO3)n1
# c1ccc2c(-c3ccc4c(c3)OCO4)c[nH]c2c1
# COc1cccc(-c2ccc3c(c2)OCO3)c1
# Fc1ccc(-c2ccc3c(c2)OCO3)c(C(F)(F)F)c1
# c1ccc(Cn2cc(-c3ccc4c(c3)OCO4)cn2)cc1
# Oc1cccc(-c2ccc3c(c2)OCO3)c1
# COc1cccc(F)c1Cc1ccc2c(c1)OCO2
# O[C@H]1C[C@@H](c2ccc3c(c2)OCO3)C1
# CC(=O)Nc1cccc(-c2ccc3c(c2)OCO3)c1
# c1ccn2c(-c3ccc4c(c3)OCO4)cnc2c1
# COc1ccncc1Nc1ccc2c(c1)OCO2
# c1ccc2cc(-c3ccc4c(c3)OCO4)ccc2c1
# c1ccc2sc(Cc3ccc4c(c3)OCO4)nc2c1
# Fc1cccc(F)c1-c1ccc2c(c1)OCO2
# OCc1cccc(-c2ccc3c(c2)OCO3)c1
# CCC(=O)Nc1ccc2c(c1)OCO2
# Cc1nc(C)c(-c2ccc3c(c2)OCO3)s1
# Fc1cc(F)cc(Cc2ccc3c(c2)OCO3)c1
# Clc1ccc(-c2ccc3c(c2)OCO3)s1
# c1cc(Cc2ccc3c(c2)OCO3)c2sccc2c1
# Cn1cncc1-c1ccc2c(c1)OCO2
# c1ccc2ncc(Nc3ccc4c(c3)OCO4)cc2c1
# COc1ccc(-c2ccc3c(c2)OCO3)cc1Cl
# c1cncc(Nc2ccc3c(c2)OCO3)c1
# c1ccc(-c2ncc(-c3ccc4c(c3)OCO4)[nH]2)cc1
# c1ccc2c(-c3ccc4c(c3)OCO4)ccnc2c1
# Cc1nc(N)sc1-c1ccc2c(c1)OCO2
# c1cc2c(-c3ccc4c(c3)OCO4)c[nH]c2cn1
# c1cc(Nc2ccc3c(c2)OCO3)ccn1
# c1cc(-c2ccc3c(c2)OCO3)ncn1
# c1cnn2c(-c3ccc4c(c3)OCO4)cnc2c1
# c1cnc2c(Cc3ccc4c(c3)OCO4)c[nH]c2c1
# Cc1cc(-c2ccc3c(c2)OCO3)no1
# c1cc(-c2ccc3c(c2)OCO3)n[nH]1
# c1csc(-c2ccc3c(c2)OCO3)c1
# Clc1cccc(Cl)c1-c1ccc2c(c1)OCO2
# FC(F)(F)c1cccc(-c2ccc3c(c2)OCO3)c1
# COc1ccc(C#N)cc1Cc1ccc2c(c1)OCO2
# c1cc2c(cc1-c1cnoc1)OCO2
# OC[C@H](Cc1ccccc1)c1ccc2c(c1)OCO2c1ccc2sc(-c3ccc4c(c3)OCO4)nc2c1C1=C(c2c[nH]c3ccccc23)CCN(c2ccc3c(c2)OCO3)C1C[C@@H](O)[C@@H](C)Oc1ccc(O)cc1Oc1ncccc1-c1ccc2c(c1)OCO2Oc1ccc(-c2ccccc2Br)cc1Oc1ccc(NCc2cccnc2)cc1Cc1ccc(-c2ccc(O)cc2)c(Br)c1
#
#
#
#
#
#
#
# CNC(=O)c1ccccc1-c1ccc(O)cc1
# N#CCC(=O)N1CCC[C@@H](c2ccc3c(c2)OCO3)C1
# Cc1ncc(-c2ccc(O)cc2)[nH]1
# Oc1ccc(-c2cncc3ccccc23)cc1
# N#Cc1ccccc1-c1ccc(O)cc1
# CCOc1ccccc1-c1ccc(O)cc1
# c1cc(-c2ccc3c(c2)OCO3)c2sccc2c1
# Oc1ccc2nc(-c3ccc4c(c3)OCO4)[nH]c2c1
# Oc1ccc(-c2cnco2)cc1
# Oc1ccc(-c2cccc(O)c2)cc1
# Nc1nccc(-c2ccc(O)cc2)n1
# Oc1ccc([C@@H]2C[C@H](O)C2)cc1
# Nc1nc(-c2ccc3c(c2)OCO3)nc2ccccc12
# N#C[C@@H]1CC[C@@H](c2ccc3c(c2)OCO3)CC1
# Oc1ccc(-c2ccccc2OC(F)(F)F)cc1
# OCc1cccc(-c2ccc(O)cc2)c1
# c1cc(Cc2ccc3c(c2)OCO3)ccn1
# Oc1ccc(-c2cnc3ccccn23)cc1
# c1cnc2c(-c3ccc4c(c3)OCO4)c[nH]c2c1
# COc1cccc(-c2ccc(O)cc2)c1
# Cn1cncc1-c1ccc(O)cc1
# N#CC[C@@H]1CC[C@@H](c2ccc3c(c2)OCO3)CC1
# Oc1ccc(Cc2cc(F)cc(F)c2)cc1
# COc1ccc(-c2ccc3c(c2)OCO3)c(OC)c1
# Oc1ccc(-c2ccc3ccccc3c2)cc1
# NC(=O)c1ccccc1-c1ccc(O)cc1
# COc1ccc(C#N)cc1-c1ccc2c(c1)OCO2
# Cc1nc(C)c(-c2ccc(O)cc2)s1
# Oc1ccc(-c2ccnc3ccccc23)cc1
# N#C[C@H]1CCOC[C@@H]1c1ccc2c(c1)OCO2
# Oc1ccc(Nc2ccncc2)cc1
# Oc1ccc(-c2cnn(Cc3ccccc3)c2)cc1
# Oc1ccc(-c2ccc(Cl)s2)cc1
# Oc1ccc(-c2cc[nH]n2)cc1
# O=C(c1ccccc1)c1ccc(-c2ccc3c(c2)OCO3)cc1
# Cc1nc(N)sc1-c1ccc(O)cc1
# Oc1ccc(-c2cccs2)cc1
# CC(C)(C)Oc1ccc2c(c1)OCO2
# Oc1ccc(-c2c(F)cccc2F)cc1
# Oc1ccc(-c2cccc(C(F)(F)F)c2)cc1
# c1cc2c(cc1OC1CCOCC1)OCO2
# Oc1ccc(-c2ccco2)cc1
# CC(C)(C)CNc1ccc2c(c1)OCO2
# CC(C)(C)NS(=O)(=O)c1ccc(-c2ccc3c(c2)OCO3)cc1
# Oc1ccc(-c2cccnc2)cc1
# Oc1ccc(Nc2cccnc2)cc1
# c1cn(-c2ccc3c(c2)OCO3)cn1
# C[C@@]1(O)CC[C@H](c2ccc3c(c2)OCO3)CC1
# Oc1ccc(-c2cnc3cccnn23)cc1
# CNS(=O)(=O)c1ccc(-c2ccc3c(c2)OCO3)cc1
# Oc1ccc(-c2cnc(-c3ccccc3)[nH]2)cc1
# Nc1ncc(-c2ccc3c(c2)OCO3)s1
# C[C@H](CO)Nc1ccc(O)cc1
# Cn1cc(-c2ccc(O)cc2)cn1
# Oc1ccc(-c2c(Cl)cccc2Cl)cc1
# CS(=O)(=O)c1ccc(-c2ccc3c(c2)OCO3)cc1
# Oc1ccc(-c2ccccc2F)cc1
# Oc1ccc(-n2cnc3ccccc32)cc1
# Nc1nnc(-c2ccc3c(c2)OCO3)s1
# COc1ccc(OC)c(-c2ccc3c(c2)OCO3)c1
# NC(=O)c1c(F)cccc1-c1ccc2c(c1)OCO2
# CC(C)(C)Nc1ccc(O)cc1
# N[C@H](c1ccc(O)cc1)c1ccco1
# CC(C)COc1ccc(O)cc1
# CC(C)Nc1ccc(O)cc1
# Cc1cncc(-c2ccc3c(c2)OCO3)n1
# Oc1ccc(-c2ccccc2Cl)cc1
# c1ccc2c(c1)cnn2-c1ccc2c(c1)OCO2
# O=C(Nc1ccc(O)cc1)c1cccs1
# Cc1cc(C)cc(-c2ccc3c(c2)OCO3)c1
# Oc1ccc(OC2CCCCC2)cc1
# N#CCCc1cccc(-c2ccc(O)cc2)c1
# OCCn1cc(-c2ccc(O)cc2)cn1
# COc1cccc(F)c1-c1ccc2c(c1)OCO2
# Oc1cccc2c1cnn2-c1ccc2c(c1)OCO2
# c1ccc2[nH]c(C3CCN(c4ccc5c(c4)OCO5)CC3)nc2c1
# Cc1ccc(Cl)c(-c2ccc(O)cc2)c1
# O=C(Nc1cccc(-c2ccc(O)cc2)c1)c1ccccc1
# Oc1ccc(-c2cccc(Cl)c2Cl)cc1
# Oc1ccc(-c2ccc3c(c2)CCC3)cc1
# c1ccn2c(-c3ccc4[nH]ncc4c3)cnc2c1O[C@H]1C[C@@H](c2ccc3[nH]ncc3c2)C1O=C(c1ccccc1)c1ccc(-c2ccc(O)cc2)cc1NC(=O)c1ccccc1-c1ccc2[nH]ncc2c1COc1ccc(C#N)cc1-c1ccc(O)cc1N#C[C@H]1CCOC[C@@H]1c1ccc(O)cc1C[S@](=O)c1ccc(-c2ccc(O)cc2)cc1CCC(=O)Nc1ccc(-c2ccc(O)cc2)cc1
#
#
#
#
#
#
#
# c1ccc(Cn2cc(-c3ccc4[nH]ncc4c3)cn2)cc1
# Oc1ccc(-c2ccc(F)cc2C(F)(F)F)cc1
# Oc1ccc(OC2CCOCC2)cc1
# Fc1cc(F)cc(Cc2ccc3[nH]ncc3c2)c1
# CCN(CC)c1ccc(O)cc1
# CC(C)(C)NS(=O)(=O)c1ccc(-c2ccc(O)cc2)cc1
# Oc1ccc(Cc2cccnc2)cc1
# Fc1cccc(F)c1-c1ccc2[nH]ncc2c1
# Oc1ccc(-n2ccnc2)cc1
# Cc1nc(C)c(-c2ccc3[nH]ncc3c2)s1
# CNS(=O)(=O)c1ccc(-c2ccc(O)cc2)cc1
# c1ccc2c(-c3ccc4[nH]ncc4c3)ccnc2c1
# CC(=O)Nc1cccc(-c2ccc(O)cc2)c1
# Nc1ncc(-c2ccc(O)cc2)s1
# O=c1[nH]ccc2oc(-c3ccc(O)cc3)cc12
# c1ccc(-c2ncc(-c3ccc4[nH]ncc4c3)[nH]2)cc1
# CC(C)(C)Oc1ccc(O)cc1
# CS(=O)(=O)c1ccc(-c2ccc(O)cc2)cc1
# c1cc(-c2ccc3[nH]ncc3c2)n[nH]1
# Cc1nc(N)sc1-c1ccc2[nH]ncc2c1
# CCC(=O)Nc1ccc(O)cc1
# Nc1nnc(-c2ccc(O)cc2)s1
# Oc1ccc(-c2c[nH]c3ccccc23)cc1
# c1cc(-c2ccc3[nH]ncc3c2)ncn1
# NC(=O)c1c(F)cccc1-c1ccc(O)cc1
# CC(C)(C)CNc1ccc(O)cc1
# FC(F)(F)c1cccc(-c2ccc3[nH]ncc3c2)c1
# COc1ccc(-c2ccc(O)cc2)cc1Cl
# c1cnn2c(-c3ccc4[nH]ncc4c3)cnc2c1
# Cc1cncc(-c2ccc(O)cc2)n1
# N[C@H](c1ccc2[nH]ncc2c1)c1ccco1
# Oc1ccc(-n2ncc3ccccc32)cc1
# Cc1cc(-c2ccc(O)cc2)no1
# COc1ccncc1Nc1ccc(O)cc1
# C[C@@]1(O)CC[C@H](c2ccc(O)cc2)CC1
# c1cncc(-c2ccc3[nH]ncc3c2)c1
# COc1cccc(F)c1-c1ccc(O)cc1
# Clc1cccc(Cl)c1-c1ccc2[nH]ncc2c1
# Oc1ccc(-n2ncc3c(O)cccc32)cc1
# OCCn1cc(-c2ccc3[nH]ncc3c2)cn1
# Oc1ccc(-c2cnoc2)cc1
# Oc1ccc(Nc2cnc3ccccc3c2)cc1
# Fc1ccccc1-c1ccc2[nH]ncc2c1
# Oc1ccc(-c2nc3ccccc3s2)cc1
# COc1ccc(OC)c(-c2ccc(O)cc2)c1
# O=C(Nc1cccc(-c2ccc3[nH]ncc3c2)c1)c1ccccc1
# CC(C)(C)Nc1ccc2[nH]ncc2c1
# Oc1ccc(-c2cccnc2O)cc1
# Clc1ccccc1-c1ccc2[nH]ncc2c1
# Oc1ccc(-c2c[nH]c3cnccc23)cc1
# Cc1cc(C)cc(-c2ccc(O)cc2)c1
# CCCn1cc(-c2ccc(O)cc2)cn1
# Oc1ccc(-c2cccc3ccsc23)cc1
# Oc1ccc(-c2nc3ccc(O)cc3[nH]2)cc1
# c1cc2c(cc1-c1ccc3[nH]ncc3c1)CCC2
# c1cc2[nH]ncc2cc1OC1CCCCC1
# Brc1ccccc1-c1ccc2[nH]ncc2c1
# O=C1CCc2cccc(-c3ccc(O)cc3)c21
# Oc1ccc(N2CCC(c3nc4ccccc4[nH]3)CC2)cc1
# Oc1ccc(Cc2ccncc2)cc1
# OC[C@H](Cc1ccccc1)c1ccc(O)cc1
# Cc1ccc(-c2ccc3[nH]ncc3c2)c(Br)c1
# N#Cc1ccccc1-c1ccc2[nH]ncc2c1
# CC(C)(N)c1ccc(-c2ccc(O)cc2)cc1
# COc1ccc(-c2ccc(O)cc2)c(OC)c1
# Nc1nc(-c2ccc(O)cc2)nc2ccccc12
# Cc1ccc(Cl)c(-c2ccc3[nH]ncc3c2)c1
# FC(F)(F)Oc1ccccc1-c1ccc2[nH]ncc2c1
# N#CCC(=O)N1CCC[C@@H](c2ccc(O)cc2)C1
# CCOC(=O)Cc1ccc(O)cc1
# Oc1ccc(N2CC=C(c3c[nH]c4ccccc34)CC2)cc1
# Clc1cccc(-c2ccc3[nH]ncc3c2)c1Cl
# c1ncc(-c2ccc3[nH]ncc3c2)o1
# Oc1ccc(-c2c[nH]c3cccnc23)cc1
# N#C[C@@H]1CC[C@@H](c2ccc(O)cc2)CC1
# c1cncc(CNc2ccc3[nH]ncc3c2)c1
# CNC(=O)c1ccccc1-c1ccc2[nH]ncc2c1
# Cc1ncc(-c2ccc3[nH]ncc3c2)[nH]1
# N#CC[C@@H]1CC[C@@H](c2ccc(O)cc2)CC1
# CCOc1ccccc1-c1ccc2[nH]ncc2c1
# Nc1nccc(-c2ccc3[nH]ncc3c2)n1Oc1cccc(-c2ccc3[nH]ncc3c2)c1O=c1[nH]ccc2oc(-c3ccc4[nH]ncc4c3)cc12CC(=O)Nc1cccc(-c2ccc3[nH]ncc3c2)c1c1ccc2c(-c3ccncc3)ccnc2c1CNS(=O)(=O)c1ccc(-c2ccc3[nH]ncc3c2)cc1CC(C)(C)Oc1ccc2[nH]ncc2c1c1cn(-c2ccc3[nH]ncc3c2)cn1
#
#
#
#
#
#
#
# COc1cccc(-c2ccc3[nH]ncc3c2)c1
# Nc1ncc(-c2ccc3[nH]ncc3c2)s1
# OCc1cccc(-c2ccc3[nH]ncc3c2)c1
# c1cc(-c2cc[nH]n2)ccn1
# CS(=O)(=O)c1ccc(-c2ccc3[nH]ncc3c2)cc1
# c1ccc2cc(-c3ccc4[nH]ncc4c3)ccc2c1
# c1ccc2c(-c3ccc4[nH]ncc4c3)c[nH]c2c1
# CC(C)(C)CNc1ccc2[nH]ncc2c1
# CCC(=O)Nc1ccc2[nH]ncc2c1
# Cn1cncc1-c1ccc2[nH]ncc2c1
# FC(F)(F)c1cccc(-c2ccncc2)c1
# Nc1nnc(-c2ccc3[nH]ncc3c2)s1
# Clc1ccc(-c2ccc3[nH]ncc3c2)s1
# COc1ccc(-c2ccc3[nH]ncc3c2)cc1Cl
# NC(=O)c1c(F)cccc1-c1ccc2[nH]ncc2c1
# COc1ccncc1Nc1ccc2[nH]ncc2c1
# C[C@@]1(O)CC[C@H](c2ccc3[nH]ncc3c2)CC1
# Cc1cncc(-c2ccc3[nH]ncc3c2)n1
# c1cncc(-c2ccncc2)c1
# Cc1cc(-c2ccc3[nH]ncc3c2)no1
# c1cc(Nc2ccc3[nH]ncc3c2)ccn1
# c1ccc2c(c1)cnn2-c1ccc2[nH]ncc2c1
# c1cncc(Nc2ccc3[nH]ncc3c2)c1
# c1ccc2ncc(Nc3ccc4[nH]ncc4c3)cc2c1
# COc1ccc(OC)c(-c2ccc3[nH]ncc3c2)c1
# COc1cccc(F)c1-c1ccc2[nH]ncc2c1
# Fc1ccccc1-c1ccncc1
# c1csc(-c2ccc3[nH]ncc3c2)c1
# c1cc2[nH]ncc2cc1-c1cnoc1
# C[C@H](CO)Nc1ccc2[nH]ncc2c1
# c1cc2c(-c3ccc4[nH]ncc4c3)c[nH]c2cn1
# Clc1ccccc1-c1ccncc1
# Oc1cccc2c1cnn2-c1ccc2[nH]ncc2c1
# c1ccc2sc(-c3ccc4[nH]ncc4c3)nc2c1
# Cc1cc(C)cc(-c2ccc3[nH]ncc3c2)c1
# c1ccc2c(c1)ncn2-c1ccc2[nH]ncc2c1
# c1coc(-c2ccc3[nH]ncc3c2)c1
# CCCn1cc(-c2ccc3[nH]ncc3c2)cn1
# OC[C@H](Cc1ccccc1)c1ccc2[nH]ncc2c1
# c1cc(-c2ccc3[nH]ncc3c2)c2sccc2c1
# Brc1ccccc1-c1ccncc1
# Oc1ncccc1-c1ccc2[nH]ncc2c1
# c1ccc2[nH]c(C3CCN(c4ccc5[nH]ncc5c4)CC3)nc2c1
# O=C1CCc2cccc(-c3ccc4[nH]ncc4c3)c21
# already requested
# CC(C)Nc1ccc2[nH]ncc2c1
# N#Cc1ccccc1-c1ccncc1
# CC(C)COc1ccc2[nH]ncc2c1
# Nc1nc(-c2ccc3[nH]ncc3c2)nc2ccccc12
# CC(C)(N)c1ccc(-c2ccc3[nH]ncc3c2)cc1
# C1=C(c2c[nH]c3ccccc23)CCN(c2ccc3[nH]ncc3c2)C1
# N#CCC(=O)N1CCC[C@@H](c2ccc3[nH]ncc3c2)C1
# O=C(Nc1ccc2[nH]ncc2c1)c1cccs1
# FC(F)(F)Oc1ccccc1-c1ccncc1
# Oc1ccc2nc(-c3ccc4[nH]ncc4c3)[nH]c2c1
# CCOC(=O)Cc1ccc2[nH]ncc2c1
# N#CCCc1cccc(-c2ccc3[nH]ncc3c2)c1
# CNC(=O)c1ccccc1-c1ccncc1
# C[C@@H](O)[C@@H](C)Oc1ccc2[nH]ncc2c1
# NC(=O)c1ccccc1-c1ccncc1
# c1cnc2c(-c3ccc4[nH]ncc4c3)c[nH]c2c1
# CCC(=O)Nc1ccc(-c2ccc3[nH]ncc3c2)cc1
# C[S@](=O)c1ccc(-c2ccc3[nH]ncc3c2)cc1
# N#C[C@@H]1CC[C@@H](c2ccc3[nH]ncc3c2)CC1
# c1ccc(Cn2cc(-c3ccncc3)cn2)cc1
# c1ccc2c(-c3ccc4[nH]ncc4c3)cncc2c1
# c1cc(Cc2ccc3[nH]ncc3c2)ccn1
# Fc1ccc(-c2ccc3[nH]ncc3c2)c(C(F)(F)F)c1
# CCOc1ccccc1-c1ccncc1
# CCN(CC)c1ccc2[nH]ncc2c1
# O[C@H]1C[C@@H](c2ccncc2)C1
# COc1ccc(C#N)cc1-c1ccc2[nH]ncc2c1
# N#CC[C@@H]1CC[C@@H](c2ccc3[nH]ncc3c2)CC1
# Fc1cc(F)cc(Cc2ccncc2)c1
# c1cncc(Cc2ccc3[nH]ncc3c2)c1
# COc1ccc(-c2ccc3[nH]ncc3c2)c(OC)c1
# N#C[C@H]1CCOC[C@@H]1c1ccc2[nH]ncc2c1
# O=C(c1ccccc1)c1ccc(-c2ccc3[nH]ncc3c2)cc1
# CC(C)(C)NS(=O)(=O)c1ccc(-c2ccc3[nH]ncc3c2)cc1
# c1cc2[nH]ncc2cc1OC1CCOCC1
# Cn1cncc1-c1ccncc1COc1ccncc1Nc1ccncc1Cc1nc(N)sc1-c1ccncc1NC(=O)c1c(F)cccc1-c1ccncc1Nc1nnc(-c2ccncc2)s1Fc1cccc(F)c1-c1ccncc1c1ccc2cc(-c3ccncc3)ccc2c1COc1ccc(-c2ccncc2)cc1Cl
#
#
#
#
#
#
#
# c1ccc2c(c1)cnn2-c1ccncc1
# Clc1ccc(-c2ccncc2)s1
# c1ccc(-c2ncc(-c3ccncc3)[nH]2)cc1
# Cc1cncc(-c2ccncc2)n1
# Cc1cc(-c2ccncc2)no1
# c1cc(Nc2ccncc2)ccn1
# c1ccc2ncc(Nc3ccncc3)cc2c1
# c1cnn2c(-c3ccncc3)cnc2c1
# Oc1cccc2c1cnn2-c1ccncc1
# COc1cccc(F)c1-c1ccncc1
# c1cc(-c2ccncn2)ccn1
# c1cncc(Nc2ccncc2)c1
# c1csc(-c2ccncc2)c1
# c1cc(-c2c[nH]c3cnccc23)ccn1
# c1ccc2sc(-c3ccncc3)nc2c1
# c1cc(-c2cnoc2)ccn1
# Clc1cccc(Cl)c1-c1ccncc1
# N[C@H](c1ccncc1)c1ccco1
# c1coc(-c2ccncc2)c1
# Oc1ncccc1-c1ccncc1
# C[C@H](CO)Nc1ccncc1
# OC[C@H](Cc1ccccc1)c1ccncc1
# c1cc(-c2ccncc2)c2sccc2c1
# CCCn1cc(-c2ccncc2)cn1
# Cn1cc(-c2ccncc2)cn1
# CC(C)(C)Nc1ccncc1
# OCCn1cc(-c2ccncc2)cn1
# Oc1ccc2nc(-c3ccncc3)[nH]c2c1
# c1ccc2c(c1)ncn2-c1ccncc1
# N#CCC(=O)N1CCC[C@@H](c2ccncc2)C1
# O=C1CCc2cccc(-c3ccncc3)c21
# Nc1nc(-c2ccncc2)nc2ccccc12
# CC(C)Nc1ccncc1
# O=C(Nc1cccc(-c2ccncc2)c1)c1ccccc1
# c1cc(OC2CCCCC2)ccn1
# CC(C)COc1ccncc1
# c1cnc2c(-c3ccncc3)c[nH]c2c1
# N#C[C@@H]1CC[C@@H](c2ccncc2)CC1
# N#CCCc1cccc(-c2ccncc2)c1
# Cc1ccc(Cl)c(-c2ccncc2)c1
# c1cc(Cc2ccncc2)ccn1
# O=C(Nc1ccncc1)c1cccs1
# CC(C)(N)c1ccc(-c2ccncc2)cc1
# N#CC[C@@H]1CC[C@@H](c2ccncc2)CC1
# CCC(=O)Nc1ccc(-c2ccncc2)cc1
# COc1ccc(-c2ccncc2)c(OC)c1
# c1cc(-c2ccc3c(c2)CCC3)ccn1
# C[C@@H](O)[C@@H](C)Oc1ccncc1
# COc1ccc(C#N)cc1-c1ccncc1
# Clc1cccc(-c2ccncc2)c1Cl
# N#C[C@H]1CCOC[C@@H]1c1ccncc1
# CCOC(=O)Cc1ccncc1
# O=C(c1ccccc1)c1ccc(-c2ccncc2)cc1
# Fc1ccc(-c2ccncc2)c(C(F)(F)F)c1
# Cc1ccc(-c2ccncc2)c(Br)c1
# c1cncc(Cc2ccncc2)c1
# C[S@](=O)c1ccc(-c2ccncc2)cc1
# c1cncc(CNc2ccncc2)c1
# c1ccc2c(-c3ccncc3)cncc2c1
# c1cc(-c2cnco2)ccn1
# c1cc(OC2CCOCC2)ccn1
# CC(C)(C)Oc1ccncc1
# Cc1ncc(-c2ccncc2)[nH]1
# CC(C)(C)NS(=O)(=O)c1ccc(-c2ccncc2)cc1
# Oc1cccc(-c2ccncc2)c1
# c1cc(-n2ccnc2)ccn1
# CC(C)(C)CNc1ccncc1
# CC(=O)Nc1cccc(-c2ccncc2)c1
# CNS(=O)(=O)c1ccc(-c2ccncc2)cc1
# OCc1cccc(-c2ccncc2)c1
# CCN(CC)c1ccncc1
# CCC(=O)Nc1ccncc1
# c1ccn2c(-c3ccncc3)cnc2c1
# O=c1[nH]ccc2oc(-c3ccncc3)cc12
# Nc1nccc(-c2ccncc2)n1
# Cc1nc(C)c(-c2ccncc2)s1
# Nc1ncc(-c2ccncc2)s1
# CS(=O)(=O)c1ccc(-c2ccncc2)cc1
# c1ccc2c(-c3ccncc3)c[nH]c2c1
# COc1cccc(-c2ccncc2)c1
# Oc1cc(-c2c[nH]c3ncc(Cl)cc23)ccc1ClC[C@@]1(O)CC[C@H](c2ccncc2)CC1Nc1cc(-c2c[nH]c3ncc(Cl)cc23)[nH]n1Clc1cnc2[nH]cc(-c3cccc(Br)c3)c2c1Oc1ccc(Cl)c(-c2c[nH]c3ncc(Cl)cc23)c1Clc1cnc2[nH]cc(-c3ccccc3Cl)c2c1Cc1nc2ccc(-c3c[nH]c4ncc(Cl)cc34)cc2o1O=C1Cc2cc(-c3c[nH]c4ncc(Cl)cc34)ccc2N1
#
#
#
#
#
#
#
# OCCCc1c[nH]c2ncc(Cl)cc12
# Clc1cnc2[nH]cc(-c3n[nH]c4ccccc34)c2c1
# O=c1[nH]c2ccc(-c3c[nH]c4ncc(Cl)cc34)cc2[nH]1
# Cc1ccc(CO)cc1-c1c[nH]c2ncc(Cl)cc12
# Clc1cnc2[nH]cc(-c3cc[nH]c3)c2c1
# Oc1c(F)cc(-c2c[nH]c3ncc(Cl)cc23)cc1F
# NC(=O)[C@H]1CC[C@@H](c2c[nH]c3ncc(Cl)cc23)CC1
# Clc1cnc2[nH]cc(-c3cccs3)c2c1
# COc1ccc(OC)c(-c2ccncc2)c1
# Fc1cccc(F)c1-c1c[nH]c2ncc(Cl)cc12
# Cn1ncc(N)c1-c1c[nH]c2ncc(Cl)cc12
# COc1cc(-c2c[nH]c3ncc(Cl)cc23)ccc1O
# Oc1ncc(-c2c[nH]c3ncc(Cl)cc23)cc1Cl
# O=c1[nH][nH]c2cc(-c3c[nH]c4ncc(Cl)cc34)ccc12
# Oc1ccc(-c2c[nH]c3ncc(Cl)cc23)c(O)c1
# Cc1cc(C)cc(-c2ccncc2)c1
# C[C@H](CC(N)=O)c1c[nH]c2ncc(Cl)cc12
# Clc1cnc2[nH]cc(Nc3ccncc3)c2c1
# CNS(=O)(=O)c1ccc(-c2c[nH]c3ncc(Cl)cc23)cc1
# N#Cc1cnc(-c2c[nH]c3ncc(Cl)cc23)cn1
# CSc1cccc(-c2c[nH]c3ncc(Cl)cc23)c1
# O=c1ccccn1Cc1c[nH]c2ncc(Cl)cc12
# c1ccc2[nH]c(C3CCN(c4ccncc4)CC3)nc2c1
# COC(=O)c1ccc(Cl)c(-c2c[nH]c3ncc(Cl)cc23)c1
# CCc1cc(O)ccc1-c1c[nH]c2ncc(Cl)cc12
# Clc1cnc2[nH]cc(-c3c(Cl)cccc3Cl)c2c1
# Fc1cc(Br)ccc1-c1c[nH]c2ncc(Cl)cc12
# N#Cc1ccc(-c2c[nH]c3ncc(Cl)cc23)cc1
# COc1cc(OC)cc(-c2c[nH]c3ncc(Cl)cc23)c1
# C1=C(c2c[nH]c3ccccc23)CCN(c2ccncc2)C1
# Clc1cnc2[nH]cc(OCc3ccccc3)c2c1
# Cc1cc(O)ccc1-c1c[nH]c2ncc(Cl)cc12
# Fc1ccc(Oc2c[nH]c3ncc(Cl)cc23)cc1
# Clc1cnc2[nH]cc(-c3ccncn3)c2c1
# Clc1cnc2[nH]cc(-c3cnccn3)c2c1
# CNC(=O)c1ccc(-c2c[nH]c3ncc(Cl)cc23)cc1
# COc1ccc(-c2c[nH]c3ncc(Cl)cc23)cc1OC
# Oc1ccc(-c2c[nH]c3ncc(Cl)cc23)cc1
# Fc1ccc(Oc2c[nH]c3ncc(Cl)cc23)c(F)c1
# Cc1cccc(C)c1-c1c[nH]c2ncc(Cl)cc12
# NC(=O)c1ccc(-c2c[nH]c3ncc(Cl)cc23)cc1
# Clc1cnc2[nH]cc(COc3ccccc3Cl)c2c1
# COC(=O)c1ccc(-c2c[nH]c3ncc(Cl)cc23)o1
# Cc1csc(-c2c[nH]c3ncc(Cl)cc23)n1
# Cc1nc2ccc(-c3c[nH]c4ncc(Cl)cc34)cc2[nH]1
# Clc1cnc2[nH]cc(-c3ccncc3)c2c1
# Fc1ccccc1Oc1c[nH]c2ncc(Cl)cc12
# Clc1cnc2[nH]cc(-n3ccnc3)c2c1
# Oc1ccc(-c2c[nH]c3ncc(Cl)cc23)c(Cl)c1
# Fc1ccc(-c2c[nH]c3ncc(Cl)cc23)cc1Cl
# Clc1cnc2[nH]cc(-c3ccoc3)c2c1
# Cc1ccc(-c2c[nH]c3ncc(Cl)cc23)nc1C
# NC(=O)Nc1ccc(-c2c[nH]c3ncc(Cl)cc23)cc1
# Cn1cc(-c2c[nH]c3ncc(Cl)cc23)cn1
# Fc1ccc(-c2c[nH]c3ncc(Cl)cc23)c(Cl)c1
# CCc1sccc1-c1c[nH]c2ncc(Cl)cc12
# Cc1ncc(-c2c[nH]c3ncc(Cl)cc23)[nH]1
# OC[C@H](c1ccccc1)c1c[nH]c2ncc(Cl)cc12
# COc1cc(CCc2c[nH]c3ncc(Cl)cc23)ccc1O
# Cc1ccc(-c2c[nH]c3ncc(Cl)cc23)c(C)n1
# CS(=O)(=O)c1ccc(-c2c[nH]c3ncc(Cl)cc23)cc1
# Clc1cnc2[nH]cc(-c3cccc4ncccc34)c2c1
# Fc1ccc(Cc2c[nH]c3ncc(Cl)cc23)cc1
# Oc1c(Cl)cc(-c2c[nH]c3ncc(Cl)cc23)cc1Cl
# Nc1nccc(-c2c[nH]c3ncc(Cl)cc23)n1
# Cc1ccc(O)cc1-c1c[nH]c2ncc(Cl)cc12
# N#Cc1ccc(-c2c[nH]c3ncc(Cl)cc23)cn1
# Oc1cc(Br)cc(-c2c[nH]c3ncc(Cl)cc23)c1
# CCc1ccc(-c2c[nH]c3ncc(Cl)cc23)cc1
# Clc1cnc2[nH]cc(-c3nc4ccccc4s3)c2c1
# Fc1cccc(Cl)c1CNc1c[nH]c2ncc(Cl)cc12
# O[C@H]1C[C@@H](c2c[nH]c3ncc(Cl)cc23)C1
# Clc1cnc2[nH]cc(-c3nccs3)c2c1
# Cc1ccc(-c2c[nH]c3ncc(Cl)cc23)cc1C
# Clc1cnc2[nH]cc(-c3cnco3)c2c1
# Clc1cccc(OCc2c[nH]c3ncc(Cl)cc23)c1
# Clc1cnc2[nH]cc(-c3cn[nH]c3)c2c1
# CNC(=O)c1ccccc1-c1cc(Cl)c2cccnc2c1O
# Oc1cncc(-c2c[nH]c3ncc(Cl)cc23)c1
# Clc1cnc2[nH]cc(-c3ccc4c(c3)CCN4)c2c1
# Oc1c(-c2ccccc2OC(F)(F)F)cc(Cl)c2cccnc12Cc1ncc(-c2cc(Cl)c3cccnc3c2O)[nH]1Oc1c(-c2cnco2)cc(Cl)c2cccnc12CCOc1ccccc1-c1cc(Cl)c2cccnc2c1OCC(C)(C)NS(=O)(=O)c1ccc(-c2cc(Cl)c3cccnc3c2O)cc1Oc1c(-c2ccc(F)cc2C(F)(F)F)cc(Cl)c2cccnc12Oc1c(-c2cncc3ccccc23)cc(Cl)c2cccnc12CCN(CC)c1cc(Cl)c2cccnc2c1O
#
#
#
#
#
#
#
# already requested
# Oc1c(-c2cnn(Cc3ccccc3)c2)cc(Cl)c2cccnc12
# Nc1nccc(-c2cc(Cl)c3cccnc3c2O)n1
# Oc1c([C@@H]2C[C@H](O)C2)cc(Cl)c2cccnc12
# O=c1[nH]ccc2oc(-c3cc(Cl)c4cccnc4c3O)cc12
# Oc1c(-c2cnc3ccccn23)cc(Cl)c2cccnc12
# Oc1cccc(-c2cc(Cl)c3cccnc3c2O)c1
# CNS(=O)(=O)c1ccc(-c2cc(Cl)c3cccnc3c2O)cc1
# CC(=O)Nc1cccc(-c2cc(Cl)c3cccnc3c2O)c1
# Oc1c(-c2c(F)cccc2F)cc(Cl)c2cccnc12
# COc1cccc(-c2cc(Cl)c3cccnc3c2O)c1
# Oc1c(Cc2cc(F)cc(F)c2)cc(Cl)c2cccnc12
# OCc1cccc(-c2cc(Cl)c3cccnc3c2O)c1
# Oc1c(-c2c[nH]c3ccccc23)cc(Cl)c2cccnc12
# Cc1nc(C)c(-c2cc(Cl)c3cccnc3c2O)s1
# CCC(=O)Nc1cc(Cl)c2cccnc2c1O
# CS(=O)(=O)c1ccc(-c2cc(Cl)c3cccnc3c2O)cc1
# Oc1c(-c2ccnc3ccccc23)cc(Cl)c2cccnc12
# Oc1c(-c2cnc(-c3ccccc3)[nH]2)cc(Cl)c2cccnc12
# Oc1c(-c2ccc3ccccc3c2)cc(Cl)c2cccnc12
# Cn1cncc1-c1cc(Cl)c2cccnc2c1O
# COc1ccncc1Nc1cc(Cl)c2cccnc2c1O
# Cc1nc(N)sc1-c1cc(Cl)c2cccnc2c1O
# Oc1c(-c2cc[nH]n2)cc(Cl)c2cccnc12
# COc1ccc(-c2cc(Cl)c3cccnc3c2O)cc1Cl
# NC(=O)c1c(F)cccc1-c1cc(Cl)c2cccnc2c1O
# Oc1c(-c2ccc(Cl)s2)cc(Cl)c2cccnc12
# Oc1c(-c2ccncn2)cc(Cl)c2cccnc12
# Oc1c(Nc2ccncc2)cc(Cl)c2cccnc12
# Oc1c(-c2cnc3cccnn23)cc(Cl)c2cccnc12
# Oc1c(-c2cccc(C(F)(F)F)c2)cc(Cl)c2cccnc12
# Oc1c(Nc2cnc3ccccc3c2)cc(Cl)c2cccnc12
# Cc1cc(-c2cc(Cl)c3cccnc3c2O)no1
# Oc1c(-n2ncc3ccccc32)cc(Cl)c2cccnc12
# Oc1c(Nc2cccnc2)cc(Cl)c2cccnc12
# N[C@@H](c1ccco1)c1cc(Cl)c2cccnc2c1O
# Oc1c(-c2c(Cl)cccc2Cl)cc(Cl)c2cccnc12
# Oc1c(-c2cccs2)cc(Cl)c2cccnc12
# Oc1c(-c2cccnc2)cc(Cl)c2cccnc12
# Oc1c(-c2cnoc2)cc(Cl)c2cccnc12
# Oc1c(-c2c[nH]c3cnccc23)cc(Cl)c2cccnc12
# Oc1cccc2c1cnn2-c1cc(Cl)c2cccnc2c1O
# C[C@H](CO)Nc1cc(Cl)c2cccnc2c1O
# OCCn1cc(-c2cc(Cl)c3cccnc3c2O)cn1
# CC(C)(C)Nc1cc(Cl)c2cccnc2c1O
# Oc1c(-c2ccco2)cc(Cl)c2cccnc12
# Oc1c(-c2ccccc2F)cc(Cl)c2cccnc12
# CCCn1cc(-c2cc(Cl)c3cccnc3c2O)cn1
# OC[C@H](Cc1ccccc1)c1cc(Cl)c2cccnc2c1O
# Oc1ncccc1-c1cc(Cl)c2cccnc2c1O
# Oc1c(-n2cnc3ccccc32)cc(Cl)c2cccnc12
# O=C(Nc1cccc(-c2cc(Cl)c3cccnc3c2O)c1)c1ccccc1
# Oc1c(OC2CCCCC2)cc(Cl)c2cccnc12
# Oc1c(-c2ccccc2Cl)cc(Cl)c2cccnc12
# Cn1cc(-c2cc(Cl)c3cccnc3c2O)cn1
# N#CCC(=O)N1CCC[C@@H](c2cc(Cl)c3cccnc3c2O)C1
# Oc1ccc2nc(-c3cc(Cl)c4cccnc4c3O)[nH]c2c1
# O=C1CCc2cccc(-c3cc(Cl)c4cccnc4c3O)c21
# Oc1c(-c2ccc3c(c2)CCC3)cc(Cl)c2cccnc12
# Cc1ccc(Cl)c(-c2cc(Cl)c3cccnc3c2O)c1
# CC(C)COc1cc(Cl)c2cccnc2c1O
# CC(C)Nc1cc(Cl)c2cccnc2c1O
# N#C[C@@H]1CC[C@@H](c2cc(Cl)c3cccnc3c2O)CC1
# Oc1c(-c2ccccc2Br)cc(Cl)c2cccnc12
# Cc1ccc(-c2cc(Cl)c3cccnc3c2O)c(Br)c1
# CC(C)(N)c1ccc(-c2cc(Cl)c3cccnc3c2O)cc1
# Oc1c(Cc2ccncc2)cc(Cl)c2cccnc12
# N#CCCc1cccc(-c2cc(Cl)c3cccnc3c2O)c1
# Oc1c(-c2cccc(Cl)c2Cl)cc(Cl)c2cccnc12
# O=C(Nc1cc(Cl)c2cccnc2c1O)c1cccs1
# N#Cc1ccccc1-c1cc(Cl)c2cccnc2c1O
# N#CC[C@@H]1CC[C@@H](c2cc(Cl)c3cccnc3c2O)CC1
# COc1ccc(-c2cc(Cl)c3cccnc3c2O)c(OC)c1
# CCC(=O)Nc1ccc(-c2cc(Cl)c3cccnc3c2O)cc1
# CCOC(=O)Cc1cc(Cl)c2cccnc2c1O
# C[C@@H](O)[C@@H](C)Oc1cc(Cl)c2cccnc2c1O
# O=C(c1ccccc1)c1ccc(-c2cc(Cl)c3cccnc3c2O)cc1
# Oc1c(NCc2cccnc2)cc(Cl)c2cccnc12
# N#C[C@H]1CCOC[C@@H]1c1cc(Cl)c2cccnc2c1O
# C[S@](=O)c1ccc(-c2cc(Cl)c3cccnc3c2O)cc1
# OC[C@H](c1ccccc1)c1cnc2nc[nH]c2c1Oc1c(Cl)cc(-c2cnc3nc[nH]c3c2)cc1ClOc1c(OC2CCOCC2)cc(Cl)c2cccnc12COc1cc(CCc2cnc3nc[nH]c3c2)ccc1OOc1c(Cc2cccnc2)cc(Cl)c2cccnc12Cc1ncc(-c2cnc3nc[nH]c3c2)[nH]1CS(=O)(=O)c1ccc(-c2cnc3nc[nH]c3c2)cc1
#
# c1cc(-c2cnc3nc[nH]c3c2)c2cccnc2c1
#
#
#
#
#
# CCc1ccc(-c2cnc3nc[nH]c3c2)cc1
# Cc1ccc(O)cc1-c1cnc2nc[nH]c2c1
# N#Cc1ccc(-c2cnc3nc[nH]c3c2)cn1
# Oc1c(-n2ccnc2)cc(Cl)c2cccnc12
# c1ccc2sc(-c3cnc4nc[nH]c4c3)nc2c1
# Nc1nccc(-c2cnc3nc[nH]c3c2)n1
# c1nc2ncc(-c3cn[nH]c3)cc2[nH]1
# c1csc(-c2cnc3nc[nH]c3c2)n1
# Clc1cccc(OCc2cnc3nc[nH]c3c2)c1
# Nc1ncc(-c2cc(Cl)c3cccnc3c2O)s1
# CC(C)(C)Oc1cc(Cl)c2cccnc2c1O
# O[C@H]1C[C@@H](c2cnc3nc[nH]c3c2)C1
# Oc1cc(-c2cnc3nc[nH]c3c2)ccc1Cl
# Cc1ccc(-c2cnc3nc[nH]c3c2)cc1C
# Oc1cncc(-c2cnc3nc[nH]c3c2)c1
# Brc1cccc(-c2cnc3nc[nH]c3c2)c1
# Nc1nnc(-c2cc(Cl)c3cccnc3c2O)s1
# c1nc2ncc(-c3ccc4c(c3)CCN4)cc2[nH]1
# Clc1ccccc1-c1cnc2nc[nH]c2c1
# c1ccc2c(-c3cnc4nc[nH]c4c3)n[nH]c2c1
# OCCCc1cnc2nc[nH]c2c1
# CC(C)(C)CNc1cc(Cl)c2cccnc2c1O
# Oc1ccc(Cl)c(-c2cnc3nc[nH]c3c2)c1
# O=C1Cc2cc(-c3cnc4nc[nH]c4c3)ccc2N1
# c1cc(-c2cnc3nc[nH]c3c2)c[nH]1
# Cc1cncc(-c2cc(Cl)c3cccnc3c2O)n1
# Nc1cc(-c2cnc3nc[nH]c3c2)[nH]n1
# Fc1cccc(F)c1-c1cnc2nc[nH]c2c1
# C[C@@]1(O)CC[C@H](c2cc(Cl)c3cccnc3c2O)CC1
# c1csc(-c2cnc3nc[nH]c3c2)c1
# COc1cc(-c2cnc3nc[nH]c3c2)ccc1O
# Cc1ccc(CO)cc1-c1cnc2nc[nH]c2c1
# NC(=O)[C@H]1CC[C@@H](c2cnc3nc[nH]c3c2)CC1
# CNS(=O)(=O)c1ccc(-c2cnc3nc[nH]c3c2)cc1
# O=c1[nH]c2ccc(-c3cnc4nc[nH]c4c3)cc2[nH]1
# Oc1ccc(-c2cnc3nc[nH]c3c2)c(O)c1
# COc1cccc(F)c1-c1cc(Cl)c2cccnc2c1O
# N#Cc1cnc(-c2cnc3nc[nH]c3c2)cn1
# COc1ccc(OC)c(-c2cc(Cl)c3cccnc3c2O)c1
# C[C@H](CC(N)=O)c1cnc2nc[nH]c2c1
# Clc1cccc(Cl)c1-c1cnc2nc[nH]c2c1
# Oc1ncc(-c2cnc3nc[nH]c3c2)cc1Cl
# Oc1c(-c2nc3ccccc3s2)cc(Cl)c2cccnc12
# COC(=O)c1ccc(Cl)c(-c2cnc3nc[nH]c3c2)c1
# Cc1cc(C)cc(-c2cc(Cl)c3cccnc3c2O)c1
# Cn1ncc(N)c1-c1cnc2nc[nH]c2c1
# CCc1cc(O)ccc1-c1cnc2nc[nH]c2c1
# O=c1ccccn1Cc1cnc2nc[nH]c2c1
# N#Cc1ccc(-c2cnc3nc[nH]c3c2)cc1
# Oc1c(-c2cccc3ccsc23)cc(Cl)c2cccnc12
# Fc1ccc(Oc2cnc3nc[nH]c3c2)cc1
# c1cc(-c2cnc3nc[nH]c3c2)ncn1
# Oc1c(N2CCC(c3nc4ccccc4[nH]3)CC2)cc(Cl)c2cccnc12
# c1cc(Nc2cnc3nc[nH]c3c2)ccn1
# c1cnc(-c2cnc3nc[nH]c3c2)cn1
# COc1cc(OC)cc(-c2cnc3nc[nH]c3c2)c1
# Cc1cc(O)ccc1-c1cnc2nc[nH]c2c1
# NC(=O)c1ccc(-c2cnc3nc[nH]c3c2)cc1
# Nc1nc(-c2cc(Cl)c3cccnc3c2O)nc2ccccc12
# Fc1cc(Br)ccc1-c1cnc2nc[nH]c2c1
# Clc1ccccc1OCc1cnc2nc[nH]c2c1
# Cc1cccc(C)c1-c1cnc2nc[nH]c2c1
# Oc1c(N2CC=C(c3c[nH]c4ccccc34)CC2)cc(Cl)c2cccnc12
# COc1ccc(-c2cnc3nc[nH]c3c2)cc1OC
# CNC(=O)c1ccc(-c2cnc3nc[nH]c3c2)cc1
# COC(=O)c1ccc(-c2cnc3nc[nH]c3c2)o1
# Oc1c(-c2c[nH]c3cccnc23)cc(Cl)c2cccnc12
# c1cn(-c2cnc3nc[nH]c3c2)cn1
# Oc1ccc(-c2cnc3nc[nH]c3c2)c(Cl)c1
# Cc1csc(-c2cnc3nc[nH]c3c2)n1
# Oc1ccc(-c2cnc3nc[nH]c3c2)cc1
# c1nc2ncc(-c3ccoc3)cc2[nH]1
# CCc1sccc1-c1cnc2nc[nH]c2c1
# Fc1ccc(-c2cnc3nc[nH]c3c2)cc1Cl
# Cc1nc2ccc(-c3cnc4nc[nH]c4c3)cc2[nH]1
# c1cc(-c2cnc3nc[nH]c3c2)ccn1
# COc1ccc(C#N)cc1-c1cc(Cl)c2cccnc2c1O
# NC(=O)Nc1ccc(-c2cnc3nc[nH]c3c2)cc1
# Cc1ccc(-c2cnc3nc[nH]c3c2)nc1C
# Cn1cc(-c2cnc3nc[nH]c3c2)cn1
# Fc1ccc(Cc2cnc3nc[nH]c3c2)cc1Cn1cc(Cc2ccncc2)ccc1=OCc1ccc(-c2cnc3nc[nH]c3c2)c(C)n1Cn1cc(-c2cnc3cccnn23)ccc1=OCOCCOc1ccc(=O)n(C)c1Cn1cc(-c2ccc[nH]2)ccc1=OCn1cc(-c2ccc(Cl)cc2)ccc1=OCCc1ccc(-c2ccc(=O)n(C)c2)cc1
#
#
#
#
#
#
#
# Cn1cc(-c2ccc3c(c2)CCO3)ccc1=O
# Fc1cccc(Cl)c1CNc1cnc2nc[nH]c2c1
# Cn1cc(OCC2(C)COC2)ccc1=O
# Cn1cc(-c2ccc(OCCO)cc2)ccc1=O
# Cn1cc(-c2cccc(O)c2)ccc1=O
# Cn1cc(Cn2ccnc2)ccc1=O
# Oc1cc(Br)cc(-c2cnc3nc[nH]c3c2)c1
# COc1ccc(CNc2ccc(=O)n(C)c2)cc1
# Cn1cc(Cc2cccnc2)ccc1=O
# Cn1cc(-c2ccc(C#N)cc2)ccc1=O
# Cn1cc(-c2ccco2)ccc1=O
# COc1ccc(-c2ccc(=O)n(C)c2)cc1
# Cn1cc(-c2cccc(C3CCNCC3)c2)ccc1=O
# Cn1cc(-c2ccc(Cl)cc2Cl)ccc1=O
# Cn1cc(-c2cc3ccccc3cn2)ccc1=O
# Cc1cc(-c2ccc(=O)n(C)c2)nc(N)n1
# c1nc2ncc(-c3cnco3)cc2[nH]1
# CCOc1ccc(-c2ccc(=O)n(C)c2)cc1
# Cn1cc(Nc2ccncn2)ccc1=O
# Cn1cc(C[C@H](O)CO)ccc1=O
# Cn1cc(-c2ccsc2)ccc1=O
# Cn1cc(-c2nc3ccccc3[nH]2)ccc1=O
# Cc1nc2ccc(-c3cnc4nc[nH]c4c3)cc2o1
# CSc1cccc(-c2ccc(=O)n(C)c2)c1
# CC(=O)Nc1cccc(-c2ccc(=O)n(C)c2)c1
# Cc1n[nH]cc1-c1ccc(=O)n(C)c1
# Cc1cc(-c2ccc(=O)n(C)c2)nn1C
# Cn1cc(-c2ccc(=O)n(C)c2)c(C(F)(F)F)n1
# Cn1cc(-c2cnc(Cl)nc2)ccc1=O
# Cn1cc([C@@H]2CC[C@@H](O)CC2)ccc1=O
# Cc1cc(Nc2ccc(=O)n(C)c2)sn1
# COc1cc(-c2ccc(=O)n(C)c2)ccc1O
# Oc1c(F)cc(-c2cnc3nc[nH]c3c2)cc1F
# COc1ncccc1-c1ccc(=O)n(C)c1
# C[C@H](O)COc1ccc(-c2ccc(=O)n(C)c2)cc1
# Cn1cc(-c2cncnc2)ccc1=O
# Cc1cc(C)cc(-c2ccc(=O)n(C)c2)c1
# Cn1cc(-c2cccc3c2OCO3)ccc1=O
# Cn1cc(-c2ccc(C(N)=O)cc2)ccc1=O
# Cn1cc([C@H](CO)Cc2ccccc2)ccc1=O
# O=c1[nH][nH]c2cc(-c3cnc4nc[nH]c4c3)ccc12
# CNS(=O)(=O)c1ccc(-c2ccc(=O)n(C)c2)cc1
# Cn1cc(-c2ccc(Br)cc2)ccc1=O
# Cn1cc(Nc2ncccn2)ccc1=O
# Cn1cc(-c2cccc(S(C)(=O)=O)c2)ccc1=O
# COc1ccc2cccc(-c3ccc(=O)n(C)c3)c2c1
# Cn1cc(-c2ccc(C(F)(F)F)cc2)ccc1=O
# Cn1cc(-c2scc3c2OCCO3)ccc1=O
# CSc1cccc(-c2cnc3nc[nH]c3c2)c1
# Cn1nncc1-c1ccc(=O)n(C)c1
# Cn1cc(-c2ccc(F)cc2Cl)ccc1=O
# Cn1cc(-c2ccc(C(=O)Nc3ccccc3)cc2)ccc1=O
# CN(C)c1ccc(-c2ccc(=O)n(C)c2)cc1
# Cn1cc(-c2ccc(F)c(F)c2)ccc1=O
# Cn1cc(-n2ccnc2)ccc1=O
# COc1cc(-c2ccc(=O)n(C)c2)cc(OC)c1OC
# Cn1cc([C@H]2CC[C@@H](O)C2)ccc1=O
# Cn1cc(Cc2ccccc2O)ccc1=O
# Cn1cc(-c2ccc(C(C)(C)C)cc2)ccc1=O
# Cn1cc(-c2cccc3ccc(O)cc23)ccc1=O
# Cn1cc(-c2ccc(=O)n(C)c2)cn1
# c1ccc(COc2cnc3nc[nH]c3c2)cc1
# Cn1cc(Cc2nccc3ccccc23)ccc1=O
# COc1ccc(Cc2ccc(=O)n(C)c2)cc1
# Cn1cc(-c2ncc(Br)cn2)ccc1=O
# Cn1cc(-c2cnc3ccccc3c2)ccc1=O
# Cc1nc(C)c(-c2ccc(=O)n(C)c2)s1
# Cc1nn(C)cc1-c1ccc(=O)n(C)c1
# COc1cc(F)c(-c2ccc(=O)n(C)c2)cc1OC
# Fc1ccc(Oc2cnc3nc[nH]c3c2)c(F)c1
# COc1ccc(Cl)cc1-c1ccc(=O)n(C)c1
# Cn1cc(-c2cccc(F)c2)ccc1=O
# COc1ccc(-c2ccc(=O)n(C)c2)cc1OC
# Fc1ccccc1Oc1cnc2nc[nH]c2c1
# Cn1cc(-c2cn[nH]c2)ccc1=O
# COc1cc(-c2ccc(=O)n(C)c2)ccc1Cl
# Fc1ccc(-c2cnc3nc[nH]c3c2)c(Cl)c1
# Cn1cc(NC(=O)C2CC2)ccc1=O
# Cc1nc(Nc2ccc(=O)n(C)c2)sc1C
# Cn1cc(-c2c[nH]c3ccccc23)ccc1=O
# Cn1cc(-c2ccccc2C(N)=O)ccc1=OCn1cc(-c2ccc3ccccc3c2)ccc1=OCn1cc(-c2cscn2)ccc1=OCc1cc(Nc2ccc(=O)n(C)c2)nn1CCn1cc(-c2cnc3ccccn23)ccc1=OCn1cc(Nc2ccncc2)ccc1=OCn1cc([C@@H]2C[C@H](O)C2)ccc1=OCn1cc(-c2cccc3c2C(=O)CC3)ccc1=O
#
#
#
#
#
#
#
# Cn1cc(-c2cccs2)ccc1=O
# Cc1nc(N)sc1-c1ccc(=O)n(C)c1
# Cn1cc(-c2ccc(Cl)s2)ccc1=O
# Cn1cc(-c2cnn(Cc3ccccc3)c2)ccc1=O
# Cc1ccc(-c2ccc(=O)n(C)c2)o1
# Cn1cc(-c2ccc(C(C)(C)N)cc2)ccc1=O
# CCc1cccc(-c2ccc(=O)n(C)c2)n1
# Cn1cc(Cc2cc(F)cc(F)c2)ccc1=O
# Cn1cc(Nc2cccnc2)ccc1=O
# CC(C)Nc1ccc(=O)n(C)c1
# Cn1cc(-c2c(F)cccc2F)ccc1=O
# Cn1cc(-c2c(Cl)cccc2Cl)ccc1=O
# COc1cc(-c2ccc(=O)n(C)c2)c(OC)cc1Br
# CCOC(=O)Cc1ccc(=O)n(C)c1
# C[C@H](CO)Nc1ccc(=O)n(C)c1
# Cc1ccc(-c2ccc(=O)n(C)c2)nc1C
# Cn1cc(NC(C)(C)C)ccc1=O
# Cn1cc(-c2cccc(CCC#N)c2)ccc1=O
# Cn1cc(-c2ccnc3ccccc23)ccc1=O
# COc1cc(OC)cc(-c2ccc(=O)n(C)c2)c1
# Cn1cc(-c2cnc(-c3ccccc3)[nH]2)ccc1=O
# Cn1cc(-n2cnc3ccccc32)ccc1=O
# Cn1cc(-c2cccc(N3CCCC3=O)c2)ccc1=O
# CCC(=O)Nc1ccc(-c2ccc(=O)n(C)c2)cc1
# Cn1cc(-c2cc[nH]n2)ccc1=O
# Cn1cc(-c2ccc([S@](C)=O)cc2)ccc1=O
# Cn1cc(OC2CCCCC2)ccc1=O
# Cn1cc(-c2ccncn2)ccc1=O
# CC(C)COc1ccc(=O)n(C)c1
# Cn1cc(-c2ccc3cn[nH]c3c2)ccc1=O
# Cn1cc(-c2cccc(C(F)(F)F)c2)ccc1=O
# Cn1cc(-c2ccc(CCO)cc2)ccc1=O
# Cn1cc(-c2ccc(F)cc2C(F)(F)F)ccc1=O
# CCN(CC)c1ccc(=O)n(C)c1
# Cn1cc([C@@H](N)c2ccco2)ccc1=O
# Cc1ccc(Cl)c(-c2ccc(=O)n(C)c2)c1
# Cn1cc(-c2cccnc2)ccc1=O
# Cn1cc(NC(=O)c2cccs2)ccc1=O
# Cn1cc(-c2cc3c(=O)[nH]ccc3o2)ccc1=O
# CC(C)Oc1ccc(=O)n(C)c1
# CCC(=O)Nc1ccc(=O)n(C)c1
# COc1cc(N2CCNCC2)ccc1-c1ccc(=O)n(C)c1
# Cn1cc(-c2ccccc2F)ccc1=O
# Cn1cc(-c2cccc(Cl)c2Cl)ccc1=O
# Cn1cc(-c2cnn(CCO)c2)ccc1=O
# C[C@@H](O)[C@@H](C)Oc1ccc(=O)n(C)c1
# COc1ccc(-c2ccc(=O)n(C)c2)cc1Cl
# COc1ccncc1Nc1ccc(=O)n(C)c1
# CCn1cc(-c2ccc(=O)n(C)c2)cn1
# Cn1cc(NCc2cccnc2)ccc1=O
# Cn1cc(-c2ccccc2Cl)ccc1=O
# Cc1cc(-c2ccc(=O)n(C)c2)no1
# Cn1cc(Nc2ccc(F)cn2)ccc1=O
# Cn1cc(-c2cccc(NC(=O)c3ccccc3)c2)ccc1=O
# Cc1ncc(-c2ccc(=O)n(C)c2)[nH]1
# Cn1cc(-c2cncc3ccccc23)ccc1=O
# Cn1cc(-c2cc3ccccc3o2)ccc1=O
# Cn1cc(Nc2cnc3ccccc3c2)ccc1=O
# Cn1cc(Nc2ccccn2)ccc1=O
# Cn1cc(-c2ccccc2Br)ccc1=O
# Cn1cc(-c2cnoc2)ccc1=O
# Cn1cc(-c2cccc(CO)c2)ccc1=O
# Cn1cc(-c2ccc3c(c2)CCC3)ccc1=O
# Cn1cc(-c2ccnc(N)n2)ccc1=O
# Cn1cc(-c2cc(S(C)(=O)=O)ccc2Cl)ccc1=O
# CNC(=O)c1ccc(-c2ccc(=O)n(C)c2)cc1
# Cn1cc(-c2ccccc2C#N)ccc1=O
# Cn1cc(-c2c[nH]c3cnccc23)ccc1=O
# Cn1cncc1-c1ccc(=O)n(C)c1
# Cc1ccc(-c2ccc(=O)n(C)c2)c(Br)c1
# COC(=O)Nc1ccc(=O)n(C)c1
# CNC(=O)c1ccccc1-c1ccc(=O)n(C)c1
# CCCn1cc(-c2ccc(=O)n(C)c2)cn1
# COc1cccc(-c2ccc(=O)n(C)c2)c1
# Cn1cc([C@@H]2CCCN(C(=O)CC#N)C2)ccc1=O
# Cn1cc(-c2ccc(OC(F)(F)F)cc2)ccc1=O
# Cn1cc(-c2ccccc2OC(F)(F)F)ccc1=O
# Cn1cc(-c2cnco2)ccc1=O
# CCOc1ccccc1-c1ccc(=O)n(C)c1
# Cn1cc([C@@H]2CC[C@@H](C#N)CC2)ccc1=O
# Cn1cc(OC2CCOCC2)ccc1=OCn1cc([C@@H]2CC[C@@H](CC#N)CC2)ccc1=OO=c1ccc(Cc2nccc3ccccc23)n[nH]1CN(C)c1ccc(-c2ccc(=O)[nH]n2)cc1Cn1cc(NCC(C)(C)C)ccc1=OO=c1ccc(-c2ccc(F)c(F)c2)n[nH]1COc1ccc(Cl)cc1-c1ccc(=O)[nH]n1COc1cc(-c2ccc(=O)[nH]n2)cc(OC)c1OC
#
#
#
#
#
#
#
# Cn1cc([C@H]2CC[C@@](C)(O)CC2)ccc1=O
# O=c1ccc(Cc2ccccc2O)n[nH]1
# Cn1cc(-c2ccc(=O)[nH]n2)cn1
# Cn1cc([C@H]2COCC[C@@H]2C#N)ccc1=O
# CC(C)(C)c1ccc(-c2ccc(=O)[nH]n2)cc1
# O=c1ccc(-c2cccc(F)c2)n[nH]1
# Cn1cc(-c2cnc(N)s2)ccc1=O
# COc1ccc(OC)c(-c2ccc(=O)n(C)c2)c1
# Cc1nn(C)cc1-c1ccc(=O)[nH]n1
# Cn1cc(-c2ccc(S(=O)(=O)NC(C)(C)C)cc2)ccc1=O
# O=c1ccc(-c2cn[nH]c2)n[nH]1
# O=C(Nc1ccc(=O)[nH]n1)C1CC1
# Cc1nc(C)c(-c2ccc(=O)[nH]n2)s1
# Cn1cc(-c2nnc(N)s2)ccc1=O
# O=c1ccc(-c2cnc3ccccc3c2)n[nH]1
# Cn1cc(-c2ccc(S(C)(=O)=O)cc2)ccc1=O
# Cn1cc(N2CCC(c3nc4ccccc4[nH]3)CC2)ccc1=O
# O=c1ccc(-c2cnc3cccnn23)n[nH]1
# O=c1ccc(-c2c[nH]c3ccccc23)n[nH]1
# O=c1ccc(Cc2ccncc2)n[nH]1
# Cc1cncc(-c2ccc(=O)n(C)c2)n1
# Cn1cc(-c2cccc(F)c2C(N)=O)ccc1=O
# O=c1ccc(-c2ccc(Cl)cc2)n[nH]1
# O=c1ccc(-c2ccc[nH]2)n[nH]1
# COCCOc1ccc(=O)[nH]n1
# Cn1cc(N2CC=C(c3c[nH]c4ccccc34)CC2)ccc1=O
# Cn1cc(-n2ncc3ccccc32)ccc1=O
# O=c1ccc(-c2cccc(O)c2)n[nH]1
# COc1cccc(F)c1-c1ccc(=O)n(C)c1
# CC1(COc2ccc(=O)[nH]n2)COC1
# O=c1ccc(Cc2cccnc2)n[nH]1
# O=c1ccc(-c2ccc(OCCO)cc2)n[nH]1
# COc1ccc(-c2ccc(=O)[nH]n2)cc1
# O=c1ccc(-c2ccc3c(c2)CCO3)n[nH]1
# Cn1cc(-n2ncc3c(O)cccc32)ccc1=O
# N#Cc1ccc(-c2ccc(=O)[nH]n2)cc1
# O=c1ccc(-c2ccco2)n[nH]1
# Cn1cc(-c2nc3ccccc3s2)ccc1=O
# O=c1ccc(-c2nc3ccccc3[nH]2)n[nH]1
# O=c1ccc(C[C@H](O)CO)n[nH]1
# O=c1ccc(Cn2ccnc2)n[nH]1
# CCOc1ccc(-c2ccc(=O)[nH]n2)cc1
# O=c1ccc(-c2cccc(C3CCNCC3)c2)n[nH]1
# Cc1cc(-c2ccc(=O)[nH]n2)nc(N)n1
# Cn1cc(-c2cccnc2O)ccc1=O
# Cc1cc(Nc2ccc(=O)[nH]n2)sn1
# Cc1n[nH]cc1-c1ccc(=O)[nH]n1
# Cn1cc(-c2cccc3ccsc23)ccc1=O
# O=c1ccc(-c2cnc(Cl)nc2)n[nH]1
# O=c1ccc(-c2cc3ccccc3cn2)n[nH]1
# O=c1ccc(Nc2ccncn2)n[nH]1
# Cn1cc(-c2nc3ccc(O)cc3[nH]2)ccc1=O
# CSc1cccc(-c2ccc(=O)[nH]n2)c1
# Cn1cc(-c2nc(N)c3ccccc3n2)ccc1=O
# NC(=O)c1ccc(-c2ccc(=O)[nH]n2)cc1
# COc1ncccc1-c1ccc(=O)[nH]n1
# Cc1cc(-c2ccc(=O)[nH]n2)nn1C
# O=c1ccc(-c2cncnc2)n[nH]1
# CC(=O)Nc1cccc(-c2ccc(=O)[nH]n2)c1
# Cn1cc(-c2c[nH]c3cccnc23)ccc1=O
# COc1ccc(-c2ccc(=O)n(C)c2)c(OC)c1
# O=c1ccc(Nc2ncccn2)n[nH]1
# O=c1ccc([C@@H]2CC[C@@H](O)CC2)n[nH]1
# C[C@H](O)COc1ccc(-c2ccc(=O)[nH]n2)cc1
# CS(=O)(=O)c1cccc(-c2ccc(=O)[nH]n2)c1
# O=c1ccc(-c2ccc(Br)cc2)n[nH]1
# Cn1cc(-c2ccc(C(=O)c3ccccc3)cc2)ccc1=O
# COc1cc(-c2ccc(=O)[nH]n2)ccc1O
# COc1ccc(C#N)cc1-c1ccc(=O)n(C)c1
# O=C(Nc1ccccc1)c1ccc(-c2ccc(=O)[nH]n2)cc1
# Cn1nncc1-c1ccc(=O)[nH]n1
# CNS(=O)(=O)c1ccc(-c2ccc(=O)[nH]n2)cc1
# O=c1ccc(-c2cccc3c2OCO3)n[nH]1
# O=c1ccc([C@H](CO)Cc2ccccc2)n[nH]1
# O=c1ccc(-n2ccnc2)n[nH]1
# Cn1cc(OC(C)(C)C)ccc1=O
# O=c1ccc(-c2ccc(C(F)(F)F)cc2)n[nH]1
# O=c1ccc(-c2scc3c2OCCO3)n[nH]1
# COc1ccc(Cc2ccc(=O)[nH]n2)cc1
# O=c1ccc(-c2ccc(F)cc2Cl)n[nH]1
# CNC(=O)c1ccc(-c2ccc(=O)[nH]n2)cc1O=c1ccc([C@H]2CC[C@@H](O)C2)n[nH]1CS(=O)(=O)c1ccc(Cl)c(-c2ccc(=O)[nH]n2)c1O=c1ccc(-c2ccccc2Br)n[nH]1O=c1ccc(-c2ccc3c(c2)CCC3)n[nH]1O=c1ccc(-c2cncc3ccccc23)n[nH]1Cc1ncc(-c2ccc(=O)[nH]n2)[nH]1COc1cc(F)c(-c2ccc(=O)[nH]n2)cc1OC
#
#
#
#
#
#
#
# COC(=O)Nc1ccc(=O)[nH]n1
# O=c1ccc(-c2ncc(Br)cn2)n[nH]1
# Nc1nccc(-c2ccc(=O)[nH]n2)n1
# N#Cc1ccccc1-c1ccc(=O)[nH]n1
# CNC(=O)c1ccccc1-c1ccc(=O)[nH]n1
# Cc1ccc(-c2ccc(=O)[nH]n2)c(Br)c1
# O=c1ccc(-c2cccc(CO)c2)n[nH]1
# COc1cc(-c2ccc(=O)[nH]n2)ccc1Cl
# COc1ccc(-c2ccc(=O)[nH]n2)cc1OC
# O=c1ccc(-c2ccc(OC(F)(F)F)cc2)n[nH]1
# COc1cccc(-c2ccc(=O)[nH]n2)c1
# CCOc1ccccc1-c1ccc(=O)[nH]n1
# O=c1ccc(-c2cnco2)n[nH]1
# O=c1ccc(-c2ccccc2OC(F)(F)F)n[nH]1
# CCc1ccc(-c2ccc(=O)[nH]n2)cc1
# Cc1nc(Nc2ccc(=O)[nH]n2)sc1C
# O=c1ccc([C@@H]2C[C@H](O)C2)n[nH]1
# O=c1ccc(-c2ccc3ccccc3c2)n[nH]1
# Cn1cncc1-c1ccc(=O)[nH]n1
# O=c1ccc(-c2cscn2)n[nH]1
# NC(=O)c1ccccc1-c1ccc(=O)[nH]n1
# COc1ccc(CNc2ccc(=O)[nH]n2)cc1
# O=c1ccc(-c2cnc3ccccn23)n[nH]1
# O=c1ccc(Cc2cc(F)cc(F)c2)n[nH]1
# O=c1ccc(-c2ccc(Cl)s2)n[nH]1
# Cc1cc(Nc2ccc(=O)[nH]n2)nn1C
# CCc1cccc(-c2ccc(=O)[nH]n2)n1
# O=c1ccc(-c2cnn(Cc3ccccc3)c2)n[nH]1
# O=c1ccc(Nc2ccncc2)n[nH]1
# O=c1ccc(-c2ccnc3ccccc23)n[nH]1
# Cc1nc(N)sc1-c1ccc(=O)[nH]n1
# O=c1ccc(-c2ccc(Cl)cc2Cl)n[nH]1
# Cc1ccc(-c2ccc(=O)[nH]n2)o1
# O=c1ccc(-c2cccs2)n[nH]1
# Cc1ccc(-c2ccc(=O)[nH]n2)nc1C
# O=c1ccc(Nc2cccnc2)n[nH]1
# O=c1ccc(-c2ccsc2)n[nH]1
# O=c1ccc(-c2c(F)cccc2F)n[nH]1
# O=c1ccc(-c2cc[nH]n2)n[nH]1
# O=c1ccc(-c2c(Cl)cccc2Cl)n[nH]1
# O=C1CCCN1c1cccc(-c2ccc(=O)[nH]n2)c1
# COc1cc(-c2ccc(=O)[nH]n2)c(OC)cc1Br
# O=c1ccc(-c2cnc(-c3ccccc3)[nH]2)n[nH]1
# C[C@H](CO)Nc1ccc(=O)[nH]n1
# CC(C)Nc1ccc(=O)[nH]n1
# O=c1ccc(-c2ccc(CCO)cc2)n[nH]1
# Cn1cc(-c2ccc(=O)[nH]n2)c(C(F)(F)F)n1
# CC(C)(C)Nc1ccc(=O)[nH]n1
# O=c1ccc(-c2cccc(C(F)(F)F)c2)n[nH]1
# O=c1ccc(-n2cnc3ccccc32)n[nH]1
# COc1cc(OC)cc(-c2ccc(=O)[nH]n2)c1
# N#CCCc1cccc(-c2ccc(=O)[nH]n2)c1
# O=c1ccc(-c2ccncn2)n[nH]1
# O=c1ccc(-c2cccnc2)n[nH]1
# Cc1cc(C)cc(-c2ccc(=O)[nH]n2)c1
# O=c1ccc(-c2ccc3cn[nH]c3c2)n[nH]1
# COc1cc(N2CCNCC2)ccc1-c1ccc(=O)[nH]n1
# O=c1ccc(OC2CCCCC2)n[nH]1
# CC(C)COc1ccc(=O)[nH]n1
# O=c1ccc(-c2ccccc2F)n[nH]1
# CCC(=O)Nc1ccc(-c2ccc(=O)[nH]n2)cc1
# N[C@H](c1ccc(=O)[nH]n1)c1ccco1
# O=c1ccc(Nc2ccc(F)cn2)n[nH]1
# COc1ccc2cccc(-c3ccc(=O)[nH]n3)c2c1
# O=c1ccc(-c2ccccc2Cl)n[nH]1
# CC(C)Oc1ccc(=O)[nH]n1
# Cc1ccc(Cl)c(-c2ccc(=O)[nH]n2)c1
# O=c1ccc(Nc2ccccn2)n[nH]1
# O=C(Nc1ccc(=O)[nH]n1)c1cccs1
# O=c1ccc(-c2ccc(F)cc2C(F)(F)F)n[nH]1
# O=c1ccc(-c2cnn(CCO)c2)n[nH]1
# CCn1cc(-c2ccc(=O)[nH]n2)cn1
# O=c1ccc(-c2cccc3ccc(O)cc23)n[nH]1
# O=C(Nc1cccc(-c2ccc(=O)[nH]n2)c1)c1ccccc1
# C[C@@H](O)[C@@H](C)Oc1ccc(=O)[nH]n1
# O=c1ccc(-c2cccc(Cl)c2Cl)n[nH]1
# O=c1ccc(-c2cc3ccccc3o2)n[nH]1
# CCC(=O)Nc1ccc(=O)[nH]n1
# O=c1ccc(NCc2cccnc2)n[nH]1
# COc1ccc(-c2ccc(=O)[nH]n2)cc1Cl
# O=c1ccc(-c2nc3ccc(O)cc3[nH]2)n[nH]1O=c1ccc(-c2c[nH]c3cccnc23)n[nH]1Fc1cc(F)cc(CNc2ccncn2)c1Cc1cc(-c2ccc(=O)[nH]n2)no1c1ccc(Cn2cc(Nc3ccncn3)cn2)cc1O=c1ccc(-c2c[nH]c3cnccc23)n[nH]1Cc1nc(C)c(Nc2ccncn2)s1COc1cccc(Nc2ccncn2)c1
#
#
#
#
#
#
#
# c1ccc2c(Nc3ccncn3)ccnc2c1
# Fc1cccc(F)c1Nc1ccncn1
# COc1ccc(C#N)cc1-c1ccc(=O)[nH]n1
# COc1ccc(-c2ccc(=O)[nH]n2)c(OC)c1
# c1ccc2cc(Nc3ccncn3)ccc2c1
# c1cc(Nc2cc[nH]n2)ncn1
# Cc1nc(N)sc1Nc1ccncn1
# O=c1ccc(-c2cnoc2)n[nH]1
# O=C(c1ccccc1)c1ccc(-c2ccc(=O)[nH]n2)cc1
# c1ccc(-c2ncc(Nc3ccncn3)[nH]2)cc1
# N#CCC(=O)N1CCC[C@@H](c2ccc(=O)[nH]n2)C1
# Clc1ccc(Nc2ccncn2)s1
# CC(C)(C)Oc1ccc(=O)[nH]n1
# CCCn1cc(-c2ccc(=O)[nH]n2)cn1
# c1cnn2c(Nc3ccncn3)cnc2c1
# FC(F)(F)c1cccc(Nc2ccncn2)c1
# c1cc(Nc2ccncn2)ncn1
# N#C[C@@H]1CC[C@@H](c2ccc(=O)[nH]n2)CC1
# O=c1ccc(OC2CCOCC2)n[nH]1
# O=C1CCc2cccc(-c3ccc(=O)[nH]n3)c21
# CC(C)(C)CNc1ccc(=O)[nH]n1
# N[C@H](Nc1ccncn1)c1ccco1
# c1cncc(Nc2ccncn2)c1
# c1cncc(NNc2ccncn2)c1
# Nc1ncc(-c2ccc(=O)[nH]n2)s1
# Clc1cccc(Cl)c1Nc1ccncn1
# CC(C)(N)c1ccc(-c2ccc(=O)[nH]n2)cc1
# OCCn1cc(Nc2ccncn2)cn1
# Fc1ccccc1Nc1ccncn1
# N#CC[C@@H]1CC[C@@H](c2ccc(=O)[nH]n2)CC1
# CC(C)(C)NNc1ccncn1
# C[C@@]1(O)CC[C@H](c2ccc(=O)[nH]n2)CC1
# Nc1nnc(-c2ccc(=O)[nH]n2)s1
# Clc1ccccc1Nc1ccncn1
# C[C@H](CO)NNc1ccncn1
# O=C(Nc1cccc(Nc2ccncn2)c1)c1ccccc1
# CCOC(=O)Cc1ccc(=O)[nH]n1
# c1cc(NOC2CCCCC2)ncn1
# COc1ccc(OC)c(-c2ccc(=O)[nH]n2)c1
# Brc1ccccc1Nc1ccncn1
# N#C[C@H]1CCOC[C@@H]1c1ccc(=O)[nH]n1
# C[S@](=O)c1ccc(-c2ccc(=O)[nH]n2)cc1
# c1ccc2c(c1)ncn2Nc1ccncn1
# Cc1cncc(-c2ccc(=O)[nH]n2)n1
# c1cc(Nc2ccc3c(c2)CCC3)ncn1
# N#Cc1ccccc1Nc1ccncn1
# Cc1ccc(Cl)c(Nc2ccncn2)c1
# O=c1ccc(N2CCC(c3nc4ccccc4[nH]3)CC2)n[nH]1
# CC(C)(C)NS(=O)(=O)c1ccc(-c2ccc(=O)[nH]n2)cc1
# CC(C)CONc1ccncn1
# CCN(CC)c1ccc(=O)[nH]n1
# COc1cccc(F)c1-c1ccc(=O)[nH]n1
# FC(F)(F)Oc1ccccc1Nc1ccncn1
# Cc1ccc(Nc2ccncn2)c(Br)c1
# Clc1cccc(Nc2ccncn2)c1Cl
# O=c1ccc(N2CC=C(c3c[nH]c4ccccc34)CC2)n[nH]1
# CS(=O)(=O)c1ccc(-c2ccc(=O)[nH]n2)cc1
# O=c1ccc(-c2nc3ccccc3s2)n[nH]1
# O=C(NNc1ccncn1)c1cccs1
# c1cncc(CNNc2ccncn2)c1
# O=c1ccc(-c2cc3c(=O)[nH]ccc3o2)n[nH]1
# NC(=O)c1ccccc1Nc1ccncn1
# c1cc(Nc2cnco2)ncn1
# NC(=O)c1c(F)cccc1-c1ccc(=O)[nH]n1
# O=c1ccc(-c2cccc3ccsc23)n[nH]1
# CNC(=O)c1ccccc1Nc1ccncn1
# COc1ccncc1Nc1ccc(=O)[nH]n1
# Cc1ncc(Nc2ccncn2)[nH]1
# C[C@@H](O)[C@@H](C)ONc1ccncn1
# c1ccn2c(Nc3ccncn3)cnc2c1
# O=c1ccc(-n2ncc3ccccc32)n[nH]1
# CCOc1ccccc1Nc1ccncn1
# O=c1ccc(Nc2cnc3ccccc3c2)n[nH]1
# Nc1nc(-c2ccc(=O)[nH]n2)nc2ccccc12
# c1ccc2c(Nc3ccncn3)cncc2c1
# O[C@H]1C[C@@H](Nc2ccncn2)C1
# Oc1cccc(Nc2ccncn2)c1
# Nc1nccc(Nc2ccncn2)n1
# O=c1ccc(-n2ncc3c(O)cccc32)n[nH]1
# O=c1ccc(-c2cccnc2O)n[nH]1
# COc1cc(Nc2ccncn2)cc(OC)c1OCOCc1cccc(Nc2ccncn2)c1CS(=O)(=O)c1ccc(Nc2ccncn2)cc1CC(C)(C)CNNc1ccncn1CCC(=O)NNc1ccncn1c1ccc2c(Nc3ccncn3)c[nH]c2c1Nc1ncc(Nc2ccncn2)s1OCCc1ccc(-c2ccncn2)cc1
#
#
#
#
#
#
#
# Cc1nn(C)cc1Nc1ccncn1
# Nc1nnc(Nc2ccncn2)s1
# Cn1cncc1Nc1ccncn1
# NC(=O)c1c(F)cccc1Nc1ccncn1
# COc1ccncc1NNc1ccncn1
# Oc1cccc2c1cnn2Nc1ncc(Br)cn1
# C[C@@]1(O)CC[C@H](Nc2ccncn2)CC1
# COc1cc(N2CCNCC2)ccc1-c1ccncn1
# c1cc(NNc2ccncn2)ccn1
# COc1ccc(Nc2ccncn2)cc1Cl
# c1ccc2c(c1)cnn2Nc1ccncn1
# c1ccc2oc(-c3ccncn3)cc2c1
# Cc1cncc(Nc2ccncn2)n1
# c1csc(Nc2ccncn2)c1
# COc1ccc(OC)c(Nc2ccncn2)c1
# c1ccc2ncc(NNc3ccncn3)cc2c1
# Cc1cc(Nc2ccncn2)no1
# COc1cccc(F)c1Nc1ccncn1
# CNC(=O)c1ccc(-c2ccncn2)cc1
# Cc1cc(C)cc(Nc2ccncn2)c1
# Fc1ccc(Nc2ccncn2)nc1
# c1cc(Nc2c[nH]c3cnccc23)ncn1
# Oc1cccc2c1cnn2Nc1ccncn1
# c1ccc2sc(Nc3ccncn3)nc2c1
# c1coc(Nc2ccncn2)c1
# CS(=O)(=O)c1ccc(Cl)c(-c2ccncn2)c1
# COC(=O)Nc1ccncn1
# c1cc(Nc2cnoc2)ncn1
# c1ccc2[nH]c(C3CCN(Nc4ccncn4)CC3)nc2c1
# c1cc(Nc2ccncn2)c2sccc2c1
# OC[C@H](Cc1ccccc1)Nc1ccncn1
# FC(F)(F)Oc1ccc(-c2ccncn2)cc1
# Oc1ncccc1Nc1ccncn1
# already requested
# CC(C)NNc1ccncn1
# CNC(=O)c1ccccc1-c1ccncn1
# Nc1nc(Nc2ccncn2)nc2ccccc12
# CCCn1cc(Nc2ccncn2)cn1
# N#CCC(=O)N1CCC[C@@H](Nc2ccncn2)C1
# C1=C(c2c[nH]c3ccccc23)CCN(Nc2ccncn2)C1
# c1cc(-c2cscn2)ncn1
# Oc1ccc2nc(Nc3ccncn3)[nH]c2c1
# CCOc1ccccc1-c1ccncn1
# N#CCCc1cccc(Nc2ccncn2)c1
# c1cnc2c(Nc3ccncn3)c[nH]c2c1
# O=C1CCc2cccc(Nc3ccncn3)c21
# N#C[C@@H]1CC[C@@H](Nc2ccncn2)CC1
# CCc1cccc(-c2ccncn2)n1
# N#Cc1ccc(Nc2ccncn2)cc1
# O[C@H]1C[C@@H](c2ccncn2)C1
# c1cc(CNc2ccncn2)ccn1
# CC(C)(N)c1ccc(Nc2ccncn2)cc1
# CCC(=O)Nc1ccc(Nc2ccncn2)cc1
# Cc1n[nH]cc1Nc1ccncn1
# COc1ccc(C#N)cc1Nc1ccncn1
# N#CC[C@@H]1CC[C@@H](Nc2ccncn2)CC1
# Fc1cc(F)cc(Cc2ccncn2)c1
# Fc1ccc(Nc2ccncn2)c(C(F)(F)F)c1
# Cc1ccc(-c2ccncn2)nc1C
# CCOC(=O)CNc1ccncn1
# COc1ccc(Nc2ccncn2)c(OC)c1
# c1cncc(CNc2ccncn2)c1
# CC(=O)Nc1cccc(Nc2ccncn2)c1
# N#C[C@H]1CCOC[C@@H]1Nc1ccncn1
# COc1ncccc1Nc1ccncn1
# O=C(c1ccccc1)c1ccc(Nc2ccncn2)cc1
# c1ccc2c(-c3ccncn3)ccnc2c1
# C[S@](=O)c1ccc(Nc2ccncn2)cc1
# O=C1CCCN1c1cccc(-c2ccncn2)c1
# CC(C)(C)ONc1ccncn1
# c1cc(NOC2CCOCC2)ncn1
# CS(=O)(=O)c1cccc(Nc2ccncn2)c1
# CC(C)(C)NS(=O)(=O)c1ccc(Nc2ccncn2)cc1
# CCN(CC)Nc1ccncn1
# c1cc(-c2cc[nH]n2)ncn1
# c1cc(Nn2ccnc2)ncn1
# Cn1nncc1Nc1ccncn1
# CNS(=O)(=O)c1ccc(Nc2ccncn2)cc1
# FC(F)(F)c1cccc(-c2ccncn2)c1
# O=c1[nH]ccc2oc(Nc3ccncn3)cc12
# COc1ccc(-c2ccncn2)cc1Clc1cncc(-c2ccncn2)c1N[C@H](c1ccncn1)c1ccco1COc1ccc(-c2ccncn2)c(OC)c1c1cc(-c2c[nH]c3cnccc23)ncn1COc1ccc(C#N)cc1-c1ccncn1Cc1ccc(Cl)c(-c2ccncn2)c1C[C@@H](O)[C@@H](C)Oc1ccncn1
#
#
#
#
#
#
#
# Cc1cc(-c2ccncn2)no1
# Fc1ccccc1-c1ccncn1
# O=C(c1ccccc1)c1ccc(-c2ccncn2)cc1
# N#CCC(=O)N1CCC[C@@H](c2ccncn2)C1
# Clc1cccc(-c2ccncn2)c1Cl
# OCCn1cc(-c2ccncn2)cn1
# c1cc(-c2cnoc2)ncn1
# c1ccc2c(-c3ccncn3)cncc2c1
# CC(C)(C)Oc1ccncn1
# c1cc(OC2CCOCC2)ncn1
# Clc1ccccc1-c1ccncn1
# O=C(Nc1cccc(-c2ccncn2)c1)c1ccccc1
# Cc1ncc(-c2ccncn2)[nH]1
# OCc1cccc(-c2ccncn2)c1
# N#C[C@@H]1CC[C@@H](c2ccncn2)CC1
# CC(C)(C)CNc1ccncn1
# Brc1ccccc1-c1ccncn1
# CCCn1cc(-c2ccncn2)cn1
# Nc1ncc(-c2ccncn2)s1
# c1cc(-c2ccc3c(c2)CCC3)ncn1
# Nc1nccc(-c2ccncn2)n1
# Cn1cncc1-c1ccncn1
# N#CC[C@@H]1CC[C@@H](c2ccncn2)CC1
# O=C1CCc2cccc(-c3ccncn3)c21
# C[C@@]1(O)CC[C@H](c2ccncn2)CC1
# N#Cc1ccccc1-c1ccncn1
# Cc1ccc(-c2ccncn2)c(Br)c1
# COc1cccc(-c2ccncn2)c1
# Nc1nnc(-c2ccncn2)s1
# c1cc(Nc2ccncn2)ccn1
# N#C[C@H]1CCOC[C@@H]1c1ccncn1
# CC(C)(N)c1ccc(-c2ccncn2)cc1
# FC(F)(F)Oc1ccccc1-c1ccncn1
# COc1ccc(OC)c(-c2ccncn2)c1
# c1ccc2cc(-c3ccncn3)ccc2c1
# c1cc(-c2cnco2)ncn1
# c1csc(-c2ccncn2)c1
# Cc1cncc(-c2ccncn2)n1
# already requested
# c1ccc(Cn2cc(-c3ccncn3)cn2)cc1
# CC(C)(C)NS(=O)(=O)c1ccc(-c2ccncn2)cc1
# c1ccc2[nH]c(C3CCN(c4ccncn4)CC3)nc2c1
# CCOC(=O)Cc1ccncn1
# CC(C)Nc1ccncn1
# Clc1ccc(-c2ccncn2)s1
# c1ccn2c(-c3ccncn3)cnc2c1
# CS(=O)(=O)c1ccc(-c2ccncn2)cc1
# Fc1cccc(F)c1-c1ccncn1
# COc1cccc(F)c1-c1ccncn1
# C[S@](=O)c1ccc(-c2ccncn2)cc1
# C1=C(c2c[nH]c3ccccc23)CCN(c2ccncn2)C1
# C[C@H](CO)Nc1ccncn1
# c1ccc(-c2ncc(-c3ccncn3)[nH]2)cc1
# N#CCCc1cccc(-c2ccncn2)c1
# NC(=O)c1c(F)cccc1-c1ccncn1
# Cc1nc(N)sc1-c1ccncn1
# c1ccc2sc(-c3ccncn3)nc2c1
# c1ccc2c(c1)ncn2-c1ccncn1
# CCN(CC)c1ccncn1
# Cc1ccc(-c2ccc(C)o2)o1
# c1ccc2c(c1)cnn2-c1ccncn1
# c1cc(-c2ccncn2)ncn1
# CCC(=O)Nc1ccc(-c2ccncn2)cc1
# CC(C)COc1ccncn1
# c1cc(-c2ccncn2)c2sccc2c1
# Oc1cccc2c1cnn2-c1ccncn1
# Cc1ccc(-c2ccc(C#N)cc2)o1
# Clc1cccc(Cl)c1-c1ccncn1
# O=c1[nH]ccc2oc(-c3ccncn3)cc12
# O=C(Nc1ccncn1)c1cccs1
# Fc1ccc(-c2ccncn2)c(C(F)(F)F)c1
# CCOc1ccc(-c2ccc(C)o2)cc1
# Nc1nc(-c2ccncn2)nc2ccccc12
# CC(C)(C)Nc1ccncn1
# Oc1ccc2nc(-c3ccncn3)[nH]c2c1
# CCC(=O)Nc1ccncn1
# c1cc(OC2CCCCC2)ncn1
# COc1ccncc1Nc1ccncn1
# Cc1ccc(-c2c[nH]nc2C)o1
# c1cnc2c(-c3ccncn3)c[nH]c2c1
# CNC(=O)c1ccc(-c2ccc(C)o2)cc1COc1ncccc1-c1ccc(C)o1Cc1ccc(-c2ccc(C(F)(F)F)cc2)o1Cc1ccc(-c2cccc3ccc(O)cc23)o1Cc1ccc(-c2ccc(C(N)=O)cc2)o1Cc1ccc(-c2scc3c2OCCO3)o1Cc1ccc(-c2ccc(F)cc2Cl)o1COc1ccc(Cc2ccc(C)o2)cc1
#
#
#
#
#
#
#
# Cc1ccc(-c2ccc(C(=O)Nc3ccccc3)cc2)o1
# Cc1ccc(-c2ccc(N(C)C)cc2)o1
# Cc1ccc([C@H]2CC[C@@H](O)C2)o1
# COC(=O)Nc1ccc(C)o1
# Cc1ccc(-c2cccc(S(C)(=O)=O)c2)o1
# COc1cc(F)c(-c2ccc(C)o2)cc1OC
# Cc1ccc(Cc2ccccc2O)o1
# COc1ccc(Cl)cc1-c1ccc(C)o1
# Cc1ccc(-c2ccc(F)c(F)c2)o1
# Cc1ccc(-c2cnnn2C)o1
# Cc1ccc(-c2ncc(Br)cn2)o1
# Cc1ccc(Cc2nccc3ccccc23)o1
# Cc1ccc(-c2cn[nH]c2)o1
# COc1cc(-c2ccc(C)o2)ccc1Cl
# Cc1ccc(-c2ccc(C(C)(C)C)cc2)o1
# Cc1ccc(-c2ccc(OC(F)(F)F)cc2)o1
# COc1ccc(-c2ccc(C)o2)cc1OC
# Cc1ccc(-c2cccc(F)c2)o1
# Cc1ccc(Nc2nc(C)c(C)s2)o1
# Cc1ccc(-c2cnc3ccccc3c2)o1
# Cc1ccc(-c2sc(C)nc2C)o1
# COc1cc(-c2ccc(C)o2)cc(OC)c1OC
# CCc1ccc(-c2ccc(C)o2)cc1
# Cc1ccc(NC(=O)C2CC2)o1
# COCCOc1ccc(C)o1
# Cc1ccc(-c2c[nH]c3ccccc23)o1
# Cc1ccc(-c2cscn2)o1
# Cc1ccc(Cc2ccncc2)o1
# COc1ccc(CNc2ccc(C)o2)cc1
# Cc1ccc(Nc2cc(C)n(C)n2)o1
# Cc1ccc(-c2cnn(C)c2)o1
# Cc1ccc(-c2ccc(Cl)cc2)o1
# Cc1ccc(OCC2(C)COC2)o1
# Cc1ccc(-c2ccc[nH]2)o1
# Cc1ccc(Cc2cccnc2)o1
# CCc1cccc(-c2ccc(C)o2)n1
# Cc1ccc(-c2ccc(Cl)cc2Cl)o1
# Cc1ccc(-c2cn(C)nc2C)o1
# Cc1ccc(-c2ccc(OCCO)cc2)o1
# COc1cc(-c2ccc(C)o2)c(OC)cc1Br
# Cc1ccc(-c2ccc3c(c2)CCO3)o1
# Cc1ccc(C[C@H](O)CO)o1
# Cc1ccc(-c2ccco2)o1
# Cc1ccc(-c2ccsc2)o1
# COc1cc(OC)cc(-c2ccc(C)o2)c1
# Cc1ccc(-c2cnc3cccnn23)o1
# Cc1ccc(Cn2ccnc2)o1
# Cc1ccc(-c2ccc(C)c(C)n2)o1
# Cc1ccc(-c2cn(C)nc2C(F)(F)F)o1
# Cc1ccc(-c2cccc(C3CCNCC3)c2)o1
# Cc1cc(-c2ccc(C)o2)nc(N)n1
# Cc1ccc(-c2cnc(Cl)nc2)o1
# Cc1ccc(-c2ccc3cn[nH]c3c2)o1
# Cc1ccc(-c2cccc(O)c2)o1
# Cc1ccc(-c2cc3ccccc3cn2)o1
# Cc1ccc(-c2cccc(N3CCCC3=O)c2)o1
# Cc1cc(C)cc(-c2ccc(C)o2)c1
# Cc1ccc(-c2cc(C)n(C)n2)o1
# Cc1ccc(-c2cncnc2)o1
# CSc1cccc(-c2ccc(C)o2)c1
# Cc1ccc(OC(C)C)o1
# CC(=O)Nc1cccc(-c2ccc(C)o2)c1
# already requested
# Cc1ccc(-c2nc3ccccc3[nH]2)o1
# Cc1ccc(-c2ccc(CCO)cc2)o1
# COc1ccc2cccc(-c3ccc(C)o3)c2c1
# Cc1ccc([C@@H]2CC[C@@H](O)CC2)o1
# Cc1ccc(-c2ccc(Br)cc2)o1
# Cc1ccc(-c2ccc(OC[C@H](C)O)cc2)o1
# COc1cc(-c2ccc(C)o2)ccc1O
# CCn1cc(-c2ccc(C)o2)cn1
# COc1cc(N2CCNCC2)ccc1-c1ccc(C)o1
# Cc1ccc(-n2ccnc2)o1
# Cc1cc(Nc2ccc(C)o2)sn1
# Cc1ccc([C@H](CO)Cc2ccccc2)o1
# Cc1ccc(-c2cccc3c2OCO3)o1
# Cc1ccc(-c2cc3ccccc3o2)o1
# CNS(=O)(=O)c1ccc(-c2ccc(C)o2)cc1
# Cc1ccc(Nc2ccc(F)cn2)o1
# Cc1ccc(Nc2ccccn2)o1
# CCc1ccc(-c2ccc(Cl)cc2)o1CCc1ccc(-c2cnc3cccnn23)o1CCc1ccc(-c2ccc(CC)o2)cc1CCc1ccc(OCCOC)o1Cc1ccc(-c2cc(S(C)(=O)=O)ccc2Cl)o1CCc1ccc(Cc2ccncc2)o1CCc1ccc(Nc2cc(C)n(C)n2)o1CCc1ccc(-c2ccc[nH]2)o1
#
#
#
#
#
#
#
# CCc1ccc(-c2ccc(OCCO)cc2)o1
# CCc1ccc(-c2ccc3c(c2)CCO3)o1
# CCc1ccc(OCC2(C)COC2)o1
# CCc1ccc(NCc2ccc(OC)cc2)o1
# CCc1ccc(-c2ccc(C)o2)o1
# CCc1ccc(-c2cccc(O)c2)o1
# CCc1ccc(-c2cccc(C3CCNCC3)c2)o1
# CCc1ccc(Cc2cccnc2)o1
# CCc1ccc(-c2cc(OC)c(Br)cc2OC)o1
# CCc1ccc(Cn2ccnc2)o1
# CCc1ccc(-c2ccco2)o1
# CCc1ccc(-c2ccc(OC)cc2)o1
# CCc1ccc(-c2ccc(Cl)cc2Cl)o1
# CCc1ccc(-c2ccc(C#N)cc2)o1
# CCc1ccc(-c2cc(OC)cc(OC)c2)o1
# CCc1ccc(Nc2ccncn2)o1
# CCc1ccc(C[C@H](O)CO)o1
# CCc1ccc(-c2nc3ccccc3[nH]2)o1
# CCc1ccc(-c2cc3ccccc3cn2)o1
# CCc1ccc(-c2cc(C)nc(N)n2)o1
# CCc1ccc(-c2ccsc2)o1
# CCc1ccc(-c2ccc3cn[nH]c3c2)o1
# CCOc1ccc(-c2ccc(CC)o2)cc1
# CCc1ccc(Nc2cc(C)ns2)o1
# CCc1ccc(-c2cnc(Cl)nc2)o1
# CCc1ccc(-c2cc(C)n(C)n2)o1
# CCc1ccc(-c2cn(C)nc2C(F)(F)F)o1
# CCc1ccc(-c2cccc(NC(C)=O)c2)o1
# CCc1ccc(-c2cccc(SC)c2)o1
# CCc1ccc(OC(C)C)o1
# CCc1ccc(-c2ccc(C(N)=O)cc2)o1
# CCc1ccc(-c2c[nH]nc2C)o1
# CCc1ccc(-c2cncnc2)o1
# CCc1ccc(-c2cc(C)cc(C)c2)o1
# CCc1ccc(-c2ccc(OC[C@H](C)O)cc2)o1
# CCc1ccc(-c2ccc(O)c(OC)c2)o1
# CCc1ccc([C@@H]2CC[C@@H](O)CC2)o1
# CCc1ccc(Nc2ncccn2)o1
# CCc1ccc(-c2cccc3ccc(OC)cc23)o1
# CCc1ccc(-c2cnn(CC)c2)o1
# CCc1ccc(-c2ccc(Br)cc2)o1
# CCc1ccc(-c2cccnc2OC)o1
# CCc1ccc(-c2cccc3c2OCO3)o1
# CCc1ccc(-c2ccc(S(=O)(=O)NC)cc2)o1
# CCc1ccc([C@H](CO)Cc2ccccc2)o1
# CCc1ccc(-c2ccc(C(=O)Nc3ccccc3)cc2)o1
# CCc1ccc(-n2ccnc2)o1
# CCc1ccc(-c2cccc3ccc(O)cc23)o1
# CCc1ccc(-c2cc3ccccc3o2)o1
# CCc1ccc(-c2cccc(S(C)(=O)=O)c2)o1
# CCc1ccc(-c2ccc(C(F)(F)F)cc2)o1
# CCc1ccc(-c2ccc(F)cc2Cl)o1
# CCc1ccc(-c2scc3c2OCCO3)o1
# CCc1ccc(Cc2ccc(OC)cc2)o1
# CCc1ccc(-c2cnnn2C)o1
# CCc1ccc(-c2cc(OC)c(OC)cc2F)o1
# CCc1ccc(-c2ccc(N(C)C)cc2)o1
# CCc1ccc(-c2ccc(F)c(F)c2)o1
# CCc1ccc(Cc2nccc3ccccc23)o1
# CCc1ccc(-c2cc(Cl)ccc2OC)o1
# CCc1ccc(-c2ccc(C(=O)NC)cc2)o1
# CCc1ccc(Cc2ccccc2O)o1
# CCc1ccc([C@H]2CC[C@@H](O)C2)o1
# CCc1ccc(-c2ccc(Cl)c(OC)c2)o1
# CCc1ccc(-c2cc(OC)c(OC)c(OC)c2)o1
# CCc1ccc(-c2cn[nH]c2)o1
# CCc1ccc(-c2ccc(C(C)(C)C)cc2)o1
# CCc1ccc(NC(=O)OC)o1
# CCc1ccc(-c2cccc(F)c2)o1
# CCc1ccc(Nc2nc(C)c(C)s2)o1
# CCc1ccc(-c2ncc(Br)cn2)o1
# CCc1ccc(-c2c[nH]c3ccccc23)o1
# CCc1ccc(-c2cnc3ccccc3c2)o1
# CCc1ccc(-c2sc(C)nc2C)o1
# CCc1ccc(NC(=O)C2CC2)o1
# CCc1ccc(-c2cnn(C)c2)o1
# CCc1ccc(-c2ccc(OC(F)(F)F)cc2)o1
# CCc1ccc(-c2ccc(OC)c(OC)c2)o1
# CCc1ccc(-c2cn(C)nc2C)o1
# CCc1ccc(-c2cscn2)o1
# O[C@@H]1CC[C@@H](c2ccnc(Nc3ccccc3)n2)CC1COc1cc(-c2ccnc(Nc3ccccc3)n2)ccc1OC[C@H](O)COc1ccc(-c2ccnc(Nc3ccccc3)n2)cc1CCc1cccc(-c2ccc(CC)o2)n1COc1ncccc1-c1ccnc(Nc2ccccc2)n1Cc1cc(C)cc(-c2ccnc(Nc3ccccc3)n2)c1NC(=O)c1ccc(-c2ccnc(Nc3ccccc3)n2)cc1Brc1ccc(-c2ccnc(Nc3ccccc3)n2)cc1
#
#
#
#
#
#
#
# CS(=O)(=O)c1cccc(-c2ccnc(Nc3ccccc3)n2)c1
# CNS(=O)(=O)c1ccc(-c2ccnc(Nc3ccccc3)n2)cc1
# CCc1ccc(-c2ccc(C)c(C)n2)o1
# c1ccc(Nc2nccc(-n3ccnc3)n2)cc1
# OC[C@H](Cc1ccccc1)c1ccnc(Nc2ccccc2)n1
# c1ccc(Nc2nccc(Nc3ncccn3)n2)cc1
# COc1ccc2cccc(-c3ccnc(Nc4ccccc4)n3)c2c1
# c1ccc(Nc2nccc(-c3cccc4c3OCO4)n2)cc1
# FC(F)(F)c1ccc(-c2ccnc(Nc3ccccc3)n2)cc1
# Cn1nncc1-c1ccnc(Nc2ccccc2)n1
# CCc1ccc(-c2cccc(N3CCCC3=O)c2)o1
# O=C(Nc1ccccc1)c1ccc(-c2ccnc(Nc3ccccc3)n2)cc1
# Fc1ccc(-c2ccnc(Nc3ccccc3)n2)c(Cl)c1
# COc1ccc(Cc2ccnc(Nc3ccccc3)n2)cc1
# CN(C)c1ccc(-c2ccnc(Nc3ccccc3)n2)cc1
# c1ccc(Nc2nccc(-c3scc4c3OCCO4)n2)cc1
# Oc1ccc2cccc(-c3ccnc(Nc4ccccc4)n3)c2c1
# CCc1ccc(-c2ccc(CCO)cc2)o1
# c1ccc(Nc2nccc(Cc3nccc4ccccc34)n2)cc1
# COc1cc(-c2ccnc(Nc3ccccc3)n2)cc(OC)c1OC
# COc1ccc(Cl)cc1-c1ccnc(Nc2ccccc2)n1
# Oc1ccccc1Cc1ccnc(Nc2ccccc2)n1
# CCc1ccc(-c2ccc(N3CCNCC3)cc2OC)o1
# O[C@@H]1CC[C@H](c2ccnc(Nc3ccccc3)n2)C1
# COc1cc(F)c(-c2ccnc(Nc3ccccc3)n2)cc1OC
# c1ccc(Nc2nccc(-c3cn[nH]c3)n2)cc1
# Fc1ccc(-c2ccnc(Nc3ccccc3)n2)cc1F
# Cn1cc(-c2ccnc(Nc3ccccc3)n2)cn1
# Fc1cccc(-c2ccnc(Nc3ccccc3)n2)c1
# Brc1cnc(-c2ccnc(Nc3ccccc3)n2)nc1
# CCc1ccc(Nc2ccc(F)cn2)o1
# Cc1nc(C)c(-c2ccnc(Nc3ccccc3)n2)s1
# c1ccc(Nc2nccc(-c3c[nH]c4ccccc34)n2)cc1
# COc1cc(-c2ccnc(Nc3ccccc3)n2)ccc1Cl
# CC(C)(C)c1ccc(-c2ccnc(Nc3ccccc3)n2)cc1
# O=C(Nc1ccnc(Nc2ccccc2)n1)C1CC1
# COc1ccc(-c2ccnc(Nc3ccccc3)n2)cc1OC
# Cc1nn(C)cc1-c1ccnc(Nc2ccccc2)n1
# c1ccc(Nc2nccc(Cc3ccncc3)n2)cc1
# c1ccc(Nc2nccc(-c3cnc4ccccc4c3)n2)cc1
# c1ccc(Nc2nccc(-c3ccc[nH]3)n2)cc1
# CCc1ccc(Nc2ccccn2)o1
# Clc1ccc(-c2ccnc(Nc3ccccc3)n2)cc1
# c1ccc(Nc2nccc(-c3cnc4cccnn34)n2)cc1
# Cc1nc(Nc2ccnc(Nc3ccccc3)n2)sc1C
# CCc1ccc(-c2ccnc(Nc3ccccc3)n2)cc1
# c1ccc(Nc2nccc(Cc3cccnc3)n2)cc1
# c1ccc(Nc2nccc(-c3ccc4c(c3)CCO4)n2)cc1
# COCCOc1ccnc(Nc2ccccc2)n1
# CCc1ccc(-c2cc(S(C)(=O)=O)ccc2Cl)o1
# OCCOc1ccc(-c2ccnc(Nc3ccccc3)n2)cc1
# Oc1cccc(-c2ccnc(Nc3ccccc3)n2)c1
# Cc1cc(Nc2ccnc(Nc3ccccc3)n2)nn1C
# OC[C@@H](O)Cc1ccnc(Nc2ccccc2)n1
# COc1ccc(CNc2ccnc(Nc3ccccc3)n2)cc1
# c1ccc(Nc2nccc(Cn3ccnc3)n2)cc1
# N#Cc1ccc(-c2ccnc(Nc3ccccc3)n2)cc1
# CC1(COc2ccnc(Nc3ccccc3)n2)COC1
# COc1ccc(-c2ccnc(Nc3ccccc3)n2)cc1
# c1ccc(Nc2nccc(-c3cccc(C4CCNCC4)c3)n2)cc1
# Cc1ccc(-c2ccnc(Nc3ccccc3)n2)o1
# Clc1ncc(-c2ccnc(Nc3ccccc3)n2)cn1
# Clc1ccc(-c2ccnc(Nc3ccccc3)n2)c(Cl)c1
# c1ccc(Nc2nccc(-c3cc4ccccc4cn3)n2)cc1
# c1ccc(Nc2nccc(-c3nc4ccccc4[nH]3)n2)cc1
# CCOc1ccc(-c2ccnc(Nc3ccccc3)n2)cc1
# c1ccc(Nc2nccc(-c3ccco3)n2)cc1
# COc1cc(-c2ccnc(Nc3ccccc3)n2)c(OC)cc1Br
# c1ccc(Nc2nccc(-c3cncnc3)n2)cc1
# c1ccc(Nc2nccc(Nc3ccncn3)n2)cc1
# CC(=O)Nc1cccc(-c2ccnc(Nc3ccccc3)n2)c1
# Cc1cc(Nc2ccnc(Nc3ccccc3)n2)sn1
# c1ccc(Nc2nccc(-c3ccsc3)n2)cc1
# Cc1cc(-c2ccnc(Nc3ccccc3)n2)nc(N)n1
# COc1cc(OC)cc(-c2ccnc(Nc3ccccc3)n2)c1
# Cc1cc(-c2ccnc(Nc3ccccc3)n2)nn1C
# Cc1n[nH]cc1-c1ccnc(Nc2ccccc2)n1
# Cn1cc(-c2ccnc(Nc3ccccc3)n2)c(C(F)(F)F)n1
# CSc1cccc(-c2ccnc(Nc3ccccc3)n2)c1
# c1ccc(Nc2nccc(-c3ccc4cn[nH]c4c3)n2)cc1
# CC(C)Oc1ccnc(Nc2ccccc2)n1Fc1ccc(Oc2ccnc(Nc3ccccc3)n2)cc1O=c1[nH][nH]c2cc(-c3ccnc(Nc4ccccc4)n3)ccc12COc1cc(N2CCNCC2)ccc1-c1ccnc(Nc2ccccc2)n1OC[C@H](c1ccccc1)c1ccnc(Nc2ccccc2)n1Nc1cc(-c2ccnc(Nc3ccccc3)n2)[nH]n1Oc1cncc(-c2ccnc(Nc3ccccc3)n2)c1COc1cc(CCc2ccnc(Nc3ccccc3)n2)ccc1O
#
#
#
#
#
#
#
# O=c1[nH]c2ccc(-c3ccnc(Nc4ccccc4)n3)cc2[nH]1
# Fc1ccc(Nc2ccnc(Nc3ccccc3)n2)nc1
# Cc1ccc(O)cc1-c1ccnc(Nc2ccccc2)n1
# c1ccc(COc2ccnc(Nc3ccccc3)n2)cc1
# Oc1ccc(-c2ccnc(Nc3ccccc3)n2)c(Cl)c1
# O=C1Cc2cc(-c3ccnc(Nc4ccccc4)n3)ccc2N1
# CCn1cc(-c2ccnc(Nc3ccccc3)n2)cn1
# N#Cc1ccc(-c2ccnc(Nc3ccccc3)n2)cn1
# Cn1ncc(N)c1-c1ccnc(Nc2ccccc2)n1
# c1ccc(Nc2nccc(Nc3ccccn3)n2)cc1
# Cc1ccc(-c2ccnc(Nc3ccccc3)n2)cc1C
# Fc1ccc(Oc2ccnc(Nc3ccccc3)n2)c(F)c1
# NC(=O)[C@H]1CC[C@@H](c2ccnc(Nc3ccccc3)n2)CC1
# Cc1ncc(-c2ccnc(Nc3ccccc3)n2)[nH]1
# c1ccc(Nc2nccc(-c3cc4ccccc4o3)n2)cc1
# c1ccc(Nc2nccc(Nc3ccncc3)n2)cc1
# CS(=O)(=O)c1ccc(Cl)c(-c2ccnc(Nc3ccccc3)n2)c1
# Clc1cccc(OCc2ccnc(Nc3ccccc3)n2)c1
# Oc1ccc(Cl)c(-c2ccnc(Nc3ccccc3)n2)c1
# Fc1ccccc1Oc1ccnc(Nc2ccccc2)n1
# C[C@H](CC(N)=O)c1ccnc(Nc2ccccc2)n1
# Fc1cc(Br)ccc1-c1ccnc(Nc2ccccc2)n1
# Nc1nccc(-c2ccnc(Nc3ccccc3)n2)n1
# CNC(=O)c1ccc(-c2ccnc(Nc3ccccc3)n2)cc1
# Cc1ccc(CO)cc1-c1ccnc(Nc2ccccc2)n1
# already requested
# c1ccc(Nc2nccc(-c3ccncc3)n2)cc1
# Brc1cccc(-c2ccnc(Nc3ccccc3)n2)c1
# Fc1ccc(Cc2ccnc(Nc3ccccc3)n2)cc1
# Cc1csc(-c2ccnc(Nc3ccccc3)n2)n1
# CCc1cc(O)ccc1-c1ccnc(Nc2ccccc2)n1
# O[C@H]1C[C@@H](c2ccnc(Nc3ccccc3)n2)C1
# COC(=O)Nc1ccnc(Nc2ccccc2)n1
# OCCCc1ccnc(Nc2ccccc2)n1
# c1ccc(Nc2nccc(-c3cccc4ncccc34)n2)cc1
# Oc1ncc(-c2ccnc(Nc3ccccc3)n2)cc1Cl
# Cc1cc(O)ccc1-c1ccnc(Nc2ccccc2)n1
# Cc1ccc(-c2ccnc(Nc3ccccc3)n2)c(C)n1
# Fc1cccc(Cl)c1CNc1ccnc(Nc2ccccc2)n1
# c1ccc(Nc2nccc(-c3cccs3)n2)cc1
# FC(F)(F)Oc1ccc(-c2ccnc(Nc3ccccc3)n2)cc1
# Clc1ccccc1-c1ccnc(Nc2ccccc2)n1
# O=c1ccccn1Cc1ccnc(Nc2ccccc2)n1
# already requested
# c1ccc(Nc2nccc(-c3n[nH]c4ccccc34)n2)cc1
# Cc1cccc(C)c1-c1ccnc(Nc2ccccc2)n1
# N#Cc1ccc([C@@H]2CCc3[nH]ncc3C2)cc1
# Oc1ccc(-c2ccnc(Nc3ccccc3)n2)c(O)c1
# Oc1cc(Br)cc(-c2ccnc(Nc3ccccc3)n2)c1
# c1ccc(Nc2nccc(-c3cscn3)n2)cc1
# c1ccc(Nc2nccc(-c3cc[nH]c3)n2)cc1
# Cc1nc2ccc(-c3ccnc(Nc4ccccc4)n3)cc2[nH]1
# Fc1cccc(F)c1-c1ccnc(Nc2ccccc2)n1
# CCOc1ccc([C@@H]2CCc3[nH]ncc3C2)cc1
# COC(=O)c1ccc(Cl)c(-c2ccnc(Nc3ccccc3)n2)c1
# CCc1sccc1-c1ccnc(Nc2ccccc2)n1
# CCc1cccc(-c2ccnc(Nc3ccccc3)n2)n1
# c1ccc(Nc2nccc(-c3cnco3)n2)cc1
# Clc1cccc(Cl)c1-c1ccnc(Nc2ccccc2)n1
# N#Cc1cnc(-c2ccnc(Nc3ccccc3)n2)cn1
# Cc1n[nH]cc1[C@@H]1CCc2[nH]ncc2C1
# NC(=O)Nc1ccc(-c2ccnc(Nc3ccccc3)n2)cc1
# Oc1c(Cl)cc(-c2ccnc(Nc3ccccc3)n2)cc1Cl
# Cc1ccc(-c2ccnc(Nc3ccccc3)n2)nc1C
# c1ccc(Nc2nccc(-c3ccncn3)n2)cc1
# c1ccc(Nc2nccc(-c3cnccn3)n2)cc1
# CS(=O)(=O)c1ccc(-c2ccnc(Nc3ccccc3)n2)cc1
# Cc1nc2ccc(-c3ccnc(Nc4ccccc4)n3)cc2o1
# COc1ncccc1[C@@H]1CCc2[nH]ncc2C1
# Clc1ccccc1OCc1ccnc(Nc2ccccc2)n1
# O=C1CCCN1c1cccc(-c2ccnc(Nc3ccccc3)n2)c1
# c1ccc(Nc2nccc(-c3nccs3)n2)cc1
# Oc1c(F)cc(-c2ccnc(Nc3ccccc3)n2)cc1F
# c1ccc(Nc2nccc(-c3nc4ccccc4s3)n2)cc1
# COC(=O)c1ccc(-c2ccnc(Nc3ccccc3)n2)o1
# Fc1ccc(-c2ccnc(Nc3ccccc3)n2)cc1Cl
# OCCc1ccc(-c2ccnc(Nc3ccccc3)n2)cc1

# %%
# does not do anything

# from multiprocessing.pool import Pool, ThreadPool
# from multiprocessing import cpu_count
# import pandas as pd

# def worker(process_pool, index, split):
#     print("worker called")
#     # out = process_pool.map(myfunction, range(*split_range))
#     out = process_pool.map(call_parallel_retro, split)
#     pd.DataFrame(out).to_csv(f'filename_{index}.csv', header=False, index=False)



# N_SPLITS = 5
# n_processes = min(N_SPLITS, cpu_count())
# # split_ranges = split(RANGE_START, RANGE_STOP, N_SPLITS) # [(0, 100), (100, 200), ... (400, 500)]
# df_split = np.array_split(unique_smiles[4000:4020], N_SPLITS)
# process_pool = Pool(n_processes)
# thread_pool = ThreadPool(N_SPLITS)
# for index in range(len(df_split)):
#     split = df_split[index]
#     thread_pool.apply_async(worker, args=(process_pool, index, split))
# # wait for all threading tasks to complete:
# thread_pool.close()
# thread_pool.join()
# Out:
# worker calledworker called
# worker called
# worker calledworker called

# %%
import numpy as np
import requests
import warnings

# %%
def call_retro_parallel(smile):
    """
    One step retrosynthesis using ASKCOS for all valid build pairs of fragments.
    Saving the plausibility and the children that can build this pair according to retrosynthetic
    analysis.

    Parameters
    ----------
    pair_smiles : numpy array
        containing SMILES strings of pairs build by fragments

    Returns
    -------
    pandas DataFrame
        containing the pair, the children building this pair and their plausibility

    """
    pairs = []
    children1 = []
    children2 = []
    plausibilities = []
    # n_attempts = 5
    #print(smile)
    pairs.append(smile)
    cur_children1 = []
    cur_children2 = []
    cur_plausibilities = []
    HOST = "https://askcos.mit.edu/"
    params = {
                "smiles": smile,  # required
                # optional with defaults shown
                "max_depth": 1,  # maximum number of reaction steps
                "max_branching": 25,  # ?max number of branches are looked at to find "best"?
                "expansion_time": 20,  # how long the expansion can run
                "max_ppg": 100,  # maximum price per gram
                "template_count": 100,
                # "max_cum_prob"
                # which common probability reached until no more templates are used
                "max_cum_prob": 0.995,
                # "chemical_property_logic"
                # molecules are buyable or not, can be 'none' (only price relevant),
                # 'and' (price and heavy atoms constraint) or
                # 'or' (one of both constraints is relevant)
                "chemical_property_logic": "none",
                # max heavy atom contraints if 'and' or 'or' is used in 'chemical_property_logic'
                "max_chemprop_c": 0,
                "max_chemprop_n": 0,
                "max_chemprop_o": 0,
                "max_chemprop_h": 0,
                # want to use popular chemicals as reasonable stopping points?
                "chemical_popularity_logic": "none",
                "min_chempop_reactants": 5,  # min frequence as popular reactant
                "min_chempop_products": 5,  # min frequence as popular prouct
                "filter_threshold": 0.75,
                "return_first": "true",  # default is false
    }
            # for attempt in range(n_attempts):
    # try:
    resp = requests.get(HOST + "/api/treebuilder/", params=params,
                                    verify=False)
    # except requests.exceptions.Timeout as err:
    #     print(err)
    #     sleep(50)
    #     continue
    retro = resp.json()

    if "trees" in retro:
        if (len(retro["trees"])) > 0:
            for num_tree in range(0, len(retro["trees"])):
                if len(retro["trees"][num_tree]["children"][0]["children"]) == 2:
                    plausibility = retro["trees"][0]["children"][0]["plausibility"]
                    child1 = retro["trees"][num_tree]["children"][0]["children"][0][
                                "smiles"
                    ]
                    child2 = retro["trees"][num_tree]["children"][0]["children"][1][
                                "smiles"
                    ]
                    cur_children1.append(child1)
                    cur_children2.append(child2)
                    cur_plausibilities.append(plausibility)

        else:
            cur_children1.append(None)
            cur_children2.append(None)
            cur_plausibilities.append(0)
    else:
        cur_children1.append(None)
        cur_children2.append(None)
        cur_plausibilities.append(0)
    children1.append(cur_children1)
    children2.append(cur_children2)
    plausibilities.append(cur_plausibilities)

    res = pd.DataFrame(
        list(zip(pairs, children1, children2, plausibilities)),
        columns=["pair", "child 1", "child 2", "plausibility"],
    )

    return res

# %%
# %%time
warnings.filterwarnings("ignore")
def worker(working_queue, output_queue):
    while True:
        if working_queue.empty() == True:
            break #this is the so-called 'poison pill'    
        else:
            smiles = working_queue.get() #get smiles from working queue
            res = call_retro_parallel(smiles)
            #call askcos for one smiles
            #then save result string to output_queue
            for i, row in res.iterrows():
                output_queue.put(str(row['pair']) + "; " + str(row['child 1']) + "; " + str(row['child 2']) + "; " + str(row['plausibility']) + "\n")
        if output_queue.qsize() > 100:
            print("Size of output_queue > 100.")
            print("Writing output_queue to file..")
            with open("retro.txt", "a+") as f_object:
                while True:
                    if output_q.empty() == True:
                        break
                    else:
                        f_object.write(output_q.get_nowait())
            f_object.close()
    return

filtered_smiles = []
for smiles in unique_smiles:
    if not smiles in open('retro.txt').read():
        filtered_smiles.append(smiles)
print(len(filtered_smiles))
working_q = mp.Queue()
output_q = mp.Queue()
for f_smiles in filtered_smiles:
    working_q.put(f_smiles)
processes = [mp.Process(target=worker,args=(working_q, output_q)) for i in range(mp.cpu_count())]
for proc in processes:
    proc.start()
for proc in processes:
    proc.join()
with open("retro.txt", "a+") as f_object:
    while True:
        if output_q.empty() == True:
            break
        f_object.write(output_q.get_nowait())
f_object.close()
# Out:
# 9277
# Size of output_queue > 100.
# Writing output_queue to file..
# Size of output_queue > 100.
# Writing output_queue to file..
# Size of output_queue > 100.
# Writing output_queue to file..
# Size of output_queue > 100.
# Writing output_queue to file..

# %%
retro_data = pd.read_csv('retro.txt', sep="; ", header=None)
retro_data
# Out:
#                                        0  \
# 0            Cc1cc(Nc2ccc(C#N)cc2)[nH]n1
# 1            CCOc1ccc(Nc2cc(C)n[nH]2)cc1
# 2              Cc1cc(Nc2c[nH]nc2C)[nH]n1
# 3               COc1ncccc1Nc1cc(C)n[nH]1
# 4     Cc1cc(Nc2cccc(S(C)(=O)=O)c2)[nH]n1
# ...                                  ...
# 5626            COc1ccc(Cc2ccc(N)nc2)cc1
# 5627                Nc1ccc(-c2cncnc2)cn1
# 5628              Nc1ccc(C[C@H](O)CO)cn1
# 5629          COc1ccc(Cl)cc1-c1ccc(N)nc1
# 5630            Nc1ccc(-c2ccc(Br)cc2)cn1
#
#                                                       1  \
# 0     ['Cc1cc(N)[nH]n1', 'Cc1cc(Cl)[nH]n1', 'Cc1cc(N...
# 1                                   ['CCOc1ccc(Br)cc1']
# 2                                                [None]
# 3                                                [None]
# 4     ['CS(=O)(=O)c1cccc(B(O)O)c1', 'CS(=O)(=O)c1ccc...
# ...                                                 ...
# 5626                                ['COc1ccc(CCl)cc1']
# 5627                                             [None]
# 5628                                             [None]
# 5629  ['CC1(C)OB(c2ccc(N)nc2)OC1(C)C', 'COc1ccc(Cl)c...
# 5630  ['CC1(C)OB(c2ccc(Br)cc2)OC1(C)C', 'Nc1ccc(I)cn...
#
#                                                       2  \
# 0     ['N#Cc1ccc(B(O)O)cc1', 'N#Cc1ccc(N)cc1', 'N#Cc...
# 1                                    ['Cc1cc(N)[nH]n1']
# 2                                                [None]
# 3                                                [None]
# 4                  ['Cc1cc(N)[nH]n1', 'Cc1cc(N)[nH]n1']
# ...                                                 ...
# 5626                                  ['Nc1ccc(Br)cn1']
# 5627                                             [None]
# 5628                                             [None]
# 5629              ['COc1ccc(Cl)cc1Br', 'Nc1ccc(Cl)cn1']
# 5630  ['Nc1ccc(Br)cn1', 'OB(O)c1ccc(Br)cc1', 'CC1(C)...
#
#                                             3
# 0     [0.999052584, 0.999052584, 0.999052584]
# 1                               [0.911036551]
# 2                                         [0]
# 3                                         [0]
# 4                  [0.996350527, 0.996350527]
# ...                                       ...
# 5626                            [0.976026356]
# 5627                                      [0]
# 5628                                      [0]
# 5629                       [0.99998, 0.99998]
# 5630  [0.999974847, 0.999974847, 0.999974847]
#
# [5631 rows x 4 columns]
